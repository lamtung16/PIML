# %%
# library
import torch
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from torchmetrics import R2Score

r2score = R2Score()

torch.manual_seed(2)
np.random.seed(2)
torch.set_printoptions(precision=8)

# %%
# Sigma function
def sigma(t, k, n):
    a = np.array([])
    for i in range(n):
        for j in range(k):
            a = np.append(a, i+1)
    a = torch.tensor(a, dtype=torch.float32)
    alpha = 16
    return 1 - torch.sigmoid(alpha*(a-t-0.5))

# %%
# Model
class Net(torch.nn.Module):
  def __init__(self, n=4, p=8, noi=1):
    super(Net, self).__init__()
    self.n   = n
    self.p   = p
    self.noi = noi
    self.k   = int(self.p/self.n)
    
    # Branch x0
    self.input_x0  = torch.nn.Linear(1, 8)
    self.hidden_x0 = torch.nn.Linear(8, 8)
    self.output_x0 = torch.nn.Linear(8, self.p)

    # Branch 1 u
    self.input1_u  = torch.nn.Linear(self.noi, 2)
    self.hidden1_u = torch.nn.Linear(2, 2)
    self.output1_u = torch.nn.Linear(2, self.k)

    # Branch 2 u
    self.input2_u  = torch.nn.Linear(self.noi, 2)
    self.hidden2_u = torch.nn.Linear(2, 2)
    self.output2_u = torch.nn.Linear(2, self.k)

    # Branch 3 u
    self.input3_u  = torch.nn.Linear(self.noi, 2)
    self.hidden3_u = torch.nn.Linear(2, 2)
    self.output3_u = torch.nn.Linear(2, self.k)

    # Branch 4 u
    self.input4_u  = torch.nn.Linear(self.noi, 2)
    self.hidden4_u = torch.nn.Linear(2, 2)
    self.output4_u = torch.nn.Linear(2, self.k)

    # Trunk
    self.input_t   = torch.nn.Linear(1, 8)
    self.hidden_t  = torch.nn.Linear(8, 8)
    self.output_t  = torch.nn.Linear(8, self.p)

  def forward(self, x0, u, t):
    # h
    h = torch.relu(self.input_x0(x0))
    h = torch.relu(self.hidden_x0(h))
    h = self.output_x0(h)

    # f
    f1 = torch.relu(self.input1_u(u[:,0:1*self.noi].reshape(-1,self.noi)))
    f1 = torch.relu(self.hidden1_u(f1))
    f1 = self.output1_u(f1)

    f2 = torch.relu(self.input2_u(u[:,1*self.noi:2*self.noi].reshape(-1,self.noi)))
    f2 = torch.relu(self.hidden2_u(f2))
    f2 = self.output2_u(f2)

    f3 = torch.relu(self.input3_u(u[:,2*self.noi:3*self.noi].reshape(-1,self.noi)))
    f3 = torch.relu(self.hidden3_u(f3))
    f3 = self.output3_u(f3)

    f4 = torch.relu(self.input4_u(u[:,3*self.noi:4*self.noi].reshape(-1,self.noi)))
    f4 = torch.relu(self.hidden4_u(f4))
    f4 = self.output4_u(f4)

    f = torch.cat((f1, f2, f3, f4), dim=1)

    # sigma
    s = sigma(t, self.k, self.n)

    # g
    g = torch.relu(self.input_t(t))
    g = torch.relu(self.hidden_t(g))
    g = self.output_t(g)

    return torch.sum(h*f*s*g + x0, dim=1).reshape(-1,1)

# %%
# Model error
def eval(model, testset):
    with torch.no_grad():
        pred_Y = model(testset.x0_data, testset.u_data, testset.t_data)

    r2 = r2score(pred_Y, testset.y_data)
    return r2.item()

# %%
# Data
class Data(torch.utils.data.Dataset):
  def __init__(self, src_file, n, H, noi):
    self.n   = n
    self.H   = H
    self.noi = noi
    self.src_file = src_file
    df = pd.read_csv(self.src_file, header=None)

    X0, U, T, Y = np.array([[1]], dtype=np.float32), np.ones((1, n*self.noi)), np.array([[1]], dtype=np.float32), np.array([[1]], dtype=np.float32)
    for i in range(df.shape[0]):
        row = np.array(df.iloc[i])
        for j in range(self.H - self.n):
            x0 = np.array([[row[self.H*self.noi + j]]])
            u  = np.array([row[j:j + self.n*self.noi]])
            for t in range(1, self.n + 1):
                y = np.array([[row[self.H*self.noi + j + t]]])
                t = np.array([[t]])

                X0 = np.concatenate((X0, x0))
                U  = np.concatenate((U, u))
                T  = np.concatenate((T, t))
                Y  = np.concatenate((Y, y))

    X0, U, T, Y = X0[1:], U[1:], T[1:], Y[1:]

    self.x0_data = torch.tensor(X0, dtype=torch.float32)
    self.u_data  = torch.tensor(U,  dtype=torch.float32)
    self.t_data  = torch.tensor(T,  dtype=torch.float32)
    self.y_data  = torch.tensor(Y,  dtype=torch.float32)

  def __len__(self):
    return len(self.x0_data)

  def __getitem__(self, idx):
    if torch.is_tensor(idx):
      idx = idx.tolist()
    x0  = self.x0_data[idx]
    u   = self.u_data[idx]
    t   = self.t_data[idx]
    y   = self.y_data[idx]
    sample = {'x0':x0, 'u':u, 't':t, 'y':y}
    return sample

# %%
# Early stopping
def early_stop(list, min_epochs, patience):
    if(len(list) > min_epochs):
        if(np.max(list[-patience:]) < 1.0001*np.max(list[0: -patience])):
            return 1
    return 0

# %%
# Plot
def plot(net, dataset, size):
    with torch.no_grad():
        pred_Y = net(dataset.x0_data, dataset.u_data, dataset.t_data)

    plt.figure(figsize=size)
    plt.plot(dataset.y_data, 'b',   label=r'real',      linewidth=3)
    plt.plot(pred_Y,         'r--', label=r'predicted', linewidth=1)
    plt.ylabel(r'x(t)')
    plt.legend()
    plt.show()

# %%
# Train function
def train(net, train_ds, test_ds, lr=0.001, min_epochs=200, max_epochs=100000, patience=100):
    loss_func  = torch.nn.MSELoss()
    optimizer  = torch.optim.Adam(net.parameters(), lr=lr)

    train_ldr = torch.utils.data.DataLoader(train_ds, batch_size=train_ds.y_data.shape[0], shuffle=True)

    R2_train = np.array([])
    R2_test  = np.array([])
    for epoch in range(0, max_epochs+1):
        net.train()
        loss  = 0
        count = 0
        for (_, batch) in enumerate(train_ldr):
            X0 = batch['x0']
            U  = batch['u']
            T  = batch['t']
            Y  = batch['y']

            optimizer.zero_grad()
            output = net(X0, U, T)             # compute the output of the Network
            loss_val = loss_func(output, Y)    # loss function
            loss += loss_val.item()            # accumulate
            loss_val.backward()                # gradients
            optimizer.step()                   # update paramters
            count += 1
        
        net.eval()
        R2_train = np.append(R2_train, eval(net, train_ds))
        R2_test  = np.append(R2_test, eval(net, test_ds))

        if(epoch%50==0):
            print("epoch = %5d \t loss = %12.4f \t R2_train = %12.4f \t R2_test = %12.4f" % (epoch, loss/count, eval(net, train_ds), eval(net, test_ds)))
        
        if(early_stop(list = R2_test, min_epochs = min_epochs, patience = patience) == 1):
            break
    
    return R2_train, R2_test

# %%
def main():

    # Hyperparameters
    p   = 8           # size of branch and trunk ouput
    n   = 4           # horizon window length
    noi = 2           # number of inputs
    H   = 512         # maximum window length

    # Create Dataset and DataLoader objects
    src_file_train = 'C:/Users/tln229/Downloads/Python/2. DeepONets/0. Data/data_10.csv'
    train_ds       = Data(src_file_train, n, H, noi)

    src_file_test  = 'C:/Users/tln229/Downloads/Python/2. DeepONets/0. Data/data_11.csv'
    test_ds        = Data(src_file_test, n, H, noi)

    # Create network
    device = torch.device("cpu")
    net = Net(n, p, noi).to(device)

    # train model
    lr         = 0.001
    min_epochs = 500
    max_epochs = 20000
    patience   = 200
    R2_train, R2_test = train(net, train_ds, test_ds, lr, min_epochs, max_epochs, patience)

    # plot
    plot(net, train_ds, (20,2))
    plot(net, test_ds,  (20,2))

    # best model
    print(np.argmax(R2_test))
    print(np.max(R2_test))

    # save
    # PATH = 'C:/Users/tln229/Downloads/Python/2. DeepONets/0. Saved models/Stacked_conditioned_Tz.pt'
    # torch.save(net, PATH)

# %%
main()
# Out:
# epoch =     0 	 loss =  232568.6719 	 R2_train =  -89590.8750 	 R2_test =  -72922.7188
# epoch =    50 	 loss =   57843.6719 	 R2_train =  -22444.5840 	 R2_test =  -22121.2207
# epoch =   100 	 loss =   18073.0391 	 R2_train =   -7157.9253 	 R2_test =   -8349.0947
# epoch =   150 	 loss =   16800.6621 	 R2_train =   -6670.1685 	 R2_test =   -8084.2236
# epoch =   200 	 loss =   15657.7051 	 R2_train =   -6220.0107 	 R2_test =   -7688.7163
# epoch =   250 	 loss =   15266.0850 	 R2_train =   -6060.9072 	 R2_test =   -7381.8018
# epoch =   300 	 loss =   14555.6494 	 R2_train =   -5774.5737 	 R2_test =   -7015.1816
# epoch =   350 	 loss =   13061.9795 	 R2_train =   -5174.0801 	 R2_test =   -6269.8838
# epoch =   400 	 loss =   10812.8711 	 R2_train =   -4274.7710 	 R2_test =   -5136.2524
# epoch =   450 	 loss =    8522.2520 	 R2_train =   -3370.0291 	 R2_test =   -3980.8479
# epoch =   500 	 loss =    6844.1470 	 R2_train =   -2707.0356 	 R2_test =   -3161.3030
# epoch =   550 	 loss =    5623.2310 	 R2_train =   -2225.6753 	 R2_test =   -2623.2075
# epoch =   600 	 loss =    4988.0073 	 R2_train =   -1978.4847 	 R2_test =   -2333.6794
# epoch =   650 	 loss =    4839.2520 	 R2_train =   -1921.3375 	 R2_test =   -2241.0247
# epoch =   700 	 loss =    4790.7300 	 R2_train =   -1902.2158 	 R2_test =   -2216.2622
# epoch =   750 	 loss =    4750.9448 	 R2_train =   -1886.4558 	 R2_test =   -2202.4055
# epoch =   800 	 loss =    4716.0991 	 R2_train =   -1872.6355 	 R2_test =   -2189.4407
# epoch =   850 	 loss =    4684.2700 	 R2_train =   -1860.0084 	 R2_test =   -2178.0820
# epoch =   900 	 loss =    4654.8203 	 R2_train =   -1848.3246 	 R2_test =   -2166.5981
# epoch =   950 	 loss =    4627.3481 	 R2_train =   -1837.4227 	 R2_test =   -2155.9058
# epoch =  1000 	 loss =    4601.5991 	 R2_train =   -1827.2047 	 R2_test =   -2144.9001
# epoch =  1050 	 loss =    4577.4087 	 R2_train =   -1817.6040 	 R2_test =   -2134.5398
# epoch =  1100 	 loss =    4554.6147 	 R2_train =   -1808.5579 	 R2_test =   -2123.3867
# epoch =  1150 	 loss =    4533.0635 	 R2_train =   -1800.0035 	 R2_test =   -2112.5840
# epoch =  1200 	 loss =    4512.5215 	 R2_train =   -1791.8479 	 R2_test =   -2102.4524
# epoch =  1250 	 loss =    4492.6709 	 R2_train =   -1783.9658 	 R2_test =   -2091.7976
# epoch =  1300 	 loss =    4473.1489 	 R2_train =   -1776.2089 	 R2_test =   -2081.6560
# epoch =  1350 	 loss =    4453.5010 	 R2_train =   -1768.3990 	 R2_test =   -2070.7820
# epoch =  1400 	 loss =    4433.2656 	 R2_train =   -1760.3522 	 R2_test =   -2059.6936
# epoch =  1450 	 loss =    4411.9351 	 R2_train =   -1751.8657 	 R2_test =   -2048.2458
# epoch =  1500 	 loss =    4388.9653 	 R2_train =   -1742.7235 	 R2_test =   -2035.8743
# epoch =  1550 	 loss =    4363.7485 	 R2_train =   -1732.6836 	 R2_test =   -2022.6788
# epoch =  1600 	 loss =    4335.5420 	 R2_train =   -1721.4482 	 R2_test =   -2008.0922
# epoch =  1650 	 loss =    4303.4458 	 R2_train =   -1708.6611 	 R2_test =   -1991.7075
# epoch =  1700 	 loss =    4266.3286 	 R2_train =   -1693.8661 	 R2_test =   -1973.0643
# epoch =  1750 	 loss =    4223.6812 	 R2_train =   -1676.8779 	 R2_test =   -1950.2784
# epoch =  1800 	 loss =    4173.9619 	 R2_train =   -1657.0513 	 R2_test =   -1928.8269
# epoch =  1850 	 loss =    4113.7720 	 R2_train =   -1633.0370 	 R2_test =   -1897.4244
# epoch =  1900 	 loss =    4039.2373 	 R2_train =   -1603.2781 	 R2_test =   -1862.2107
# epoch =  1950 	 loss =    3944.7712 	 R2_train =   -1565.5543 	 R2_test =   -1815.6169
# epoch =  2000 	 loss =    3823.2092 	 R2_train =   -1516.9772 	 R2_test =   -1761.0620
# epoch =  2050 	 loss =    3659.8198 	 R2_train =   -1451.6741 	 R2_test =   -1680.9418
# epoch =  2100 	 loss =    3431.9756 	 R2_train =   -1360.6270 	 R2_test =   -1568.0034
# epoch =  2150 	 loss =    3106.6704 	 R2_train =   -1230.3760 	 R2_test =   -1422.0773
# epoch =  2200 	 loss =    2660.4907 	 R2_train =   -1051.2743 	 R2_test =   -1202.6959
# epoch =  2250 	 loss =    2019.6428 	 R2_train =    -794.5800 	 R2_test =    -906.4741
# epoch =  2300 	 loss =    1374.6013 	 R2_train =    -550.3015 	 R2_test =    -616.1494
# epoch =  2350 	 loss =     913.1357 	 R2_train =    -358.6696 	 R2_test =    -400.6860
# epoch =  2400 	 loss =     605.7040 	 R2_train =    -238.5834 	 R2_test =    -259.2602
# epoch =  2450 	 loss =     387.6100 	 R2_train =    -151.6553 	 R2_test =    -169.7988
# epoch =  2500 	 loss =     236.4144 	 R2_train =     -91.9643 	 R2_test =    -103.5218
# epoch =  2550 	 loss =     140.1606 	 R2_train =     -54.1324 	 R2_test =     -62.2476
# epoch =  2600 	 loss =      89.5787 	 R2_train =     -34.3324 	 R2_test =     -40.3141
# epoch =  2650 	 loss =      67.5401 	 R2_train =     -25.7281 	 R2_test =     -30.5818
# epoch =  2700 	 loss =      57.4381 	 R2_train =     -21.7628 	 R2_test =     -25.9828
# epoch =  2750 	 loss =      51.1060 	 R2_train =     -19.2629 	 R2_test =     -23.0586
# epoch =  2800 	 loss =      46.1034 	 R2_train =     -17.2825 	 R2_test =     -20.7484
# epoch =  2850 	 loss =      41.8495 	 R2_train =     -15.5972 	 R2_test =     -18.7785
# epoch =  2900 	 loss =      38.1452 	 R2_train =     -14.1290 	 R2_test =     -17.0528
# epoch =  2950 	 loss =      34.8748 	 R2_train =     -12.8325 	 R2_test =     -15.5217
# epoch =  3000 	 loss =      31.9574 	 R2_train =     -11.6762 	 R2_test =     -14.1495
# epoch =  3050 	 loss =      29.3287 	 R2_train =     -10.6330 	 R2_test =     -12.9110
# epoch =  3100 	 loss =      26.9225 	 R2_train =      -9.6792 	 R2_test =     -11.7919
# epoch =  3150 	 loss =      24.7539 	 R2_train =      -8.8195 	 R2_test =     -10.7641
# epoch =  3200 	 loss =      22.7781 	 R2_train =      -8.0358 	 R2_test =      -9.8317
# epoch =  3250 	 loss =      20.9712 	 R2_train =      -7.3187 	 R2_test =      -8.9752
# epoch =  3300 	 loss =      19.3117 	 R2_train =      -6.6608 	 R2_test =      -8.1832
# epoch =  3350 	 loss =      17.7866 	 R2_train =      -6.0557 	 R2_test =      -7.4605
# epoch =  3400 	 loss =      16.3816 	 R2_train =      -5.4984 	 R2_test =      -6.7908
# epoch =  3450 	 loss =      15.0855 	 R2_train =      -4.9843 	 R2_test =      -6.1755
# epoch =  3500 	 loss =      13.8892 	 R2_train =      -4.5095 	 R2_test =      -5.6047
# epoch =  3550 	 loss =      12.7834 	 R2_train =      -4.0710 	 R2_test =      -5.0768
# epoch =  3600 	 loss =      12.1557 	 R2_train =      -3.8998 	 R2_test =      -4.8269
# epoch =  3650 	 loss =      10.9023 	 R2_train =      -3.2902 	 R2_test =      -4.1373
# epoch =  3700 	 loss =       9.9474 	 R2_train =      -2.9461 	 R2_test =      -3.7322
# epoch =  3750 	 loss =       9.1449 	 R2_train =      -2.6276 	 R2_test =      -3.3459
# epoch =  3800 	 loss =       8.4231 	 R2_train =      -2.3463 	 R2_test =      -3.0158
# epoch =  3850 	 loss =       8.1814 	 R2_train =      -2.4176 	 R2_test =      -2.9133
# epoch =  3900 	 loss =       7.0901 	 R2_train =      -1.8125 	 R2_test =      -2.3656
# epoch =  3950 	 loss =       6.5095 	 R2_train =      -1.5820 	 R2_test =      -2.0903
# epoch =  4000 	 loss =       5.9719 	 R2_train =      -1.3687 	 R2_test =      -1.8350
# epoch =  4050 	 loss =       5.4732 	 R2_train =      -1.1709 	 R2_test =      -1.5960
# epoch =  4100 	 loss =      10.4963 	 R2_train =      -2.0925 	 R2_test =      -1.9641
# epoch =  4150 	 loss =       4.6373 	 R2_train =      -0.8327 	 R2_test =      -1.1841
# epoch =  4200 	 loss =       4.2326 	 R2_train =      -0.6789 	 R2_test =      -1.0055
# epoch =  4250 	 loss =       3.8810 	 R2_train =      -0.5394 	 R2_test =      -0.8382
# epoch =  4300 	 loss =       3.5552 	 R2_train =      -0.4102 	 R2_test =      -0.6829
# epoch =  4350 	 loss =       3.3455 	 R2_train =      -1.6298 	 R2_test =      -1.1675
# epoch =  4400 	 loss =       3.0604 	 R2_train =      -0.2038 	 R2_test =      -0.4243
# epoch =  4450 	 loss =       2.7527 	 R2_train =      -0.0918 	 R2_test =      -0.3011
# epoch =  4500 	 loss =       2.5255 	 R2_train =      -0.0018 	 R2_test =      -0.1927
# epoch =  4550 	 loss =       2.3149 	 R2_train =       0.0818 	 R2_test =      -0.0930
# epoch =  4600 	 loss =       2.5622 	 R2_train =      -0.1555 	 R2_test =      -0.1868
# epoch =  4650 	 loss =       1.9692 	 R2_train =       0.2198 	 R2_test =       0.0702
# epoch =  4700 	 loss =       1.8107 	 R2_train =       0.2818 	 R2_test =       0.1464
# epoch =  4750 	 loss =       1.6669 	 R2_train =       0.3388 	 R2_test =       0.2150
# epoch =  4800 	 loss =       1.5331 	 R2_train =       0.3919 	 R2_test =       0.2782
# epoch =  4850 	 loss =       1.4088 	 R2_train =       0.4411 	 R2_test =       0.3373
# epoch =  4900 	 loss =       1.3297 	 R2_train =      -0.4748 	 R2_test =      -0.0539
# epoch =  4950 	 loss =       1.2250 	 R2_train =       0.5099 	 R2_test =       0.4318
# epoch =  5000 	 loss =       1.1156 	 R2_train =       0.5574 	 R2_test =       0.4750
# epoch =  5050 	 loss =       1.0309 	 R2_train =       0.5910 	 R2_test =       0.5158
# epoch =  5100 	 loss =       0.9522 	 R2_train =       0.6223 	 R2_test =       0.5532
# epoch =  5150 	 loss =       0.8788 	 R2_train =       0.6514 	 R2_test =       0.5880
# epoch =  5200 	 loss =       2.7491 	 R2_train =      -0.7559 	 R2_test =      -0.0373
# epoch =  5250 	 loss =       1.6243 	 R2_train =       0.5749 	 R2_test =       0.6080
# epoch =  5300 	 loss =       0.7092 	 R2_train =       0.7181 	 R2_test =       0.6653
# epoch =  5350 	 loss =       0.6605 	 R2_train =       0.7379 	 R2_test =       0.6908
# epoch =  5400 	 loss =       0.6150 	 R2_train =       0.7560 	 R2_test =       0.7119
# epoch =  5450 	 loss =       0.5726 	 R2_train =       0.7728 	 R2_test =       0.7318
# epoch =  5500 	 loss =       0.5330 	 R2_train =       0.7885 	 R2_test =       0.7502
# epoch =  5550 	 loss =       0.4966 	 R2_train =       0.8029 	 R2_test =       0.7688
# epoch =  5600 	 loss =       1.3234 	 R2_train =       0.4178 	 R2_test =       0.5434
# epoch =  5650 	 loss =      19.1408 	 R2_train =      -7.5836 	 R2_test =      -3.6586
# epoch =  5700 	 loss =       0.4817 	 R2_train =       0.8270 	 R2_test =       0.7943
# epoch =  5750 	 loss =       0.3827 	 R2_train =       0.8483 	 R2_test =       0.8206
# epoch =  5800 	 loss =       0.3592 	 R2_train =       0.8574 	 R2_test =       0.8318
# epoch =  5850 	 loss =       0.6718 	 R2_train =      -0.0805 	 R2_test =       0.4226
# epoch =  5900 	 loss =       0.3285 	 R2_train =       0.8671 	 R2_test =       0.8418
# epoch =  5950 	 loss =       0.3050 	 R2_train =       0.8790 	 R2_test =       0.8561
# epoch =  6000 	 loss =       0.2884 	 R2_train =       0.8855 	 R2_test =       0.8637
# epoch =  6050 	 loss =       0.2729 	 R2_train =       0.8917 	 R2_test =       0.8709
# epoch =  6100 	 loss =       0.2926 	 R2_train =       0.8768 	 R2_test =       0.8795
# epoch =  6150 	 loss =       0.3126 	 R2_train =       0.7872 	 R2_test =       0.8076
# epoch =  6200 	 loss =       0.2364 	 R2_train =       0.9069 	 R2_test =       0.8865
# epoch =  6250 	 loss =       0.2227 	 R2_train =       0.9116 	 R2_test =       0.8931
# epoch =  6300 	 loss =       0.4044 	 R2_train =       0.7986 	 R2_test =       0.8577
# epoch =  6350 	 loss =       0.2628 	 R2_train =       0.8902 	 R2_test =       0.8755
# epoch =  6400 	 loss =       0.1974 	 R2_train =       0.9211 	 R2_test =       0.9052
# epoch =  6450 	 loss =       0.1892 	 R2_train =       0.9249 	 R2_test =       0.9083
# epoch =  6500 	 loss =       0.1817 	 R2_train =       0.9279 	 R2_test =       0.9118
# epoch =  6550 	 loss =       0.1746 	 R2_train =       0.9307 	 R2_test =       0.9148
# epoch =  6600 	 loss =      11.4578 	 R2_train =      -5.5228 	 R2_test =      -2.1631
# epoch =  6650 	 loss =       0.1943 	 R2_train =       0.9112 	 R2_test =       0.9146
# epoch =  6700 	 loss =       0.1584 	 R2_train =       0.9370 	 R2_test =       0.9209
# epoch =  6750 	 loss =       0.1529 	 R2_train =       0.9393 	 R2_test =       0.9245
# epoch =  6800 	 loss =       0.1479 	 R2_train =       0.9413 	 R2_test =       0.9267
# epoch =  6850 	 loss =       0.1432 	 R2_train =       0.9431 	 R2_test =       0.9287
# epoch =  6900 	 loss =       5.1695 	 R2_train =      -3.3671 	 R2_test =      -1.0974
# epoch =  6950 	 loss =       0.1372 	 R2_train =       0.9312 	 R2_test =       0.9334
# epoch =  7000 	 loss =       0.1314 	 R2_train =       0.9479 	 R2_test =       0.9332
# epoch =  7050 	 loss =       0.1272 	 R2_train =       0.9495 	 R2_test =       0.9356
# epoch =  7100 	 loss =       0.3150 	 R2_train =       0.8327 	 R2_test =       0.8809
# epoch =  7150 	 loss =       0.1871 	 R2_train =       0.9199 	 R2_test =       0.9189
# epoch =  7200 	 loss =       0.1187 	 R2_train =       0.9530 	 R2_test =       0.9397
# epoch =  7250 	 loss =       0.1188 	 R2_train =       0.9523 	 R2_test =       0.9423
# epoch =  7300 	 loss =       0.2545 	 R2_train =       0.8595 	 R2_test =       0.8657
# epoch =  7350 	 loss =       0.1174 	 R2_train =       0.9548 	 R2_test =       0.9443
# epoch =  7400 	 loss =       0.1085 	 R2_train =       0.9569 	 R2_test =       0.9434
# epoch =  7450 	 loss =       0.1063 	 R2_train =       0.9578 	 R2_test =       0.9444
# epoch =  7500 	 loss =       0.1043 	 R2_train =       0.9586 	 R2_test =       0.9453
# epoch =  7550 	 loss =       0.1292 	 R2_train =       0.9434 	 R2_test =       0.9455
# epoch =  7600 	 loss =       0.8518 	 R2_train =       0.8034 	 R2_test =       0.8919
# epoch =  7650 	 loss =       0.1015 	 R2_train =       0.9606 	 R2_test =       0.9484
# epoch =  7700 	 loss =       0.0971 	 R2_train =       0.9614 	 R2_test =       0.9482
# epoch =  7750 	 loss =       0.0955 	 R2_train =       0.9621 	 R2_test =       0.9489
# epoch =  7800 	 loss =       0.0940 	 R2_train =       0.9627 	 R2_test =       0.9496
# epoch =  7850 	 loss =       0.2447 	 R2_train =       0.8644 	 R2_test =       0.9108
# epoch =  7900 	 loss =       0.2580 	 R2_train =       0.9012 	 R2_test =       0.9120
# epoch =  7950 	 loss =       0.0901 	 R2_train =       0.9644 	 R2_test =       0.9515
# epoch =  8000 	 loss =       9.5456 	 R2_train =      -0.1701 	 R2_test =       0.2806
# epoch =  8050 	 loss =       0.1336 	 R2_train =       0.9607 	 R2_test =       0.9546
# epoch =  8100 	 loss =       0.0857 	 R2_train =       0.9659 	 R2_test =       0.9526
# epoch =  8150 	 loss =       0.0846 	 R2_train =       0.9664 	 R2_test =       0.9535
# epoch =  8200 	 loss =       0.0835 	 R2_train =       0.9668 	 R2_test =       0.9539
# epoch =  8250 	 loss =       0.0862 	 R2_train =       0.9650 	 R2_test =       0.9561
# epoch =  8300 	 loss =       0.1675 	 R2_train =       0.8412 	 R2_test =       0.9110
# epoch =  8350 	 loss =       0.0807 	 R2_train =       0.9678 	 R2_test =       0.9544
# epoch =  8400 	 loss =       0.0795 	 R2_train =       0.9684 	 R2_test =       0.9557
# epoch =  8450 	 loss =       0.0786 	 R2_train =       0.9688 	 R2_test =       0.9559
# epoch =  8500 	 loss =       0.0778 	 R2_train =       0.9691 	 R2_test =       0.9562
# 8343
# 0.9568707346916199
