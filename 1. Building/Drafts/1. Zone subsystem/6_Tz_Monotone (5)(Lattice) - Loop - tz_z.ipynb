# %%
import tensorflow as tf
import tensorflow_addons as tfa
import tensorflow_lattice as tfl
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

np.random.seed(1)

# %%
# DATA
df = pd.read_csv('C:/Users/tln229/Downloads/Python/Building/data/HVAC_B90_102_exp_10m_20210424.csv')

# %%
f = open('C:/Users/tln229/Downloads/Python/Building/1. Zone subsystem/stat3.txt', 'w')

for n in ([16, 32, 64, 128]):
    for y_max in ([2, 5, 10, 20]):
        for grid_size in ([5, 10, 20, 40]):
            for lr in ([0.001, 0.005, 0.1, 0.2]):

                n_train = n

                # trainning set
                Tz_k   = np.array(df['room_temp']).reshape(-1,1)[0: n_train]
                Tsa_k1 = np.array(df['supply_discharge_temp']).reshape(-1,1)[1: n_train+1]
                msa_k1 = np.array(df['airflow_current']).reshape(-1,1)[1: n_train+1]
                Tz_k1  = np.array(df['room_temp']).reshape(-1,1)[1: n_train+1]
                z      = ((msa_k1-400)/600)*(Tsa_k1-Tz_k)

                X = np.concatenate((Tz_k, z), axis=1)
                Y = np.copy(Tz_k1)

                # test set
                Tz_k_t   = np.array(df['room_temp']).reshape(-1,1)[n_train: 1600]
                Tsa_k1_t = np.array(df['supply_discharge_temp']).reshape(-1,1)[n_train+1: 1600+1]
                msa_k1_t = np.array(df['airflow_current']).reshape(-1,1)[n_train+1: 1600+1]
                Tz_k1_t  = np.array(df['room_temp']).reshape(-1,1)[n_train+1: 1600+1]
                z_t      = ((msa_k1_t-400)/600)*(Tsa_k1_t-Tz_k_t)

                X_t = np.concatenate((Tz_k_t, z_t), axis=1)
                Y_t = np.copy(Tz_k1_t)

                # combined calibrator
                combined_calibrators = tfl.layers.ParallelCombination()

                calibrator_x1 = tfl.layers.PWLCalibration(input_keypoints=np.linspace(65,  85, grid_size), output_min=0, output_max=y_max)
                calibrator_x2 = tfl.layers.PWLCalibration(input_keypoints=np.linspace(-1,  20, grid_size), output_min=0, output_max=y_max, monotonicity='increasing')

                combined_calibrators.append(calibrator_x1)
                combined_calibrators.append(calibrator_x2)

                # Lattice
                lattice = tfl.layers.Lattice(
                    lattice_sizes = [y_max+1, y_max+1],
                    monotonicities = ['increasing', 'increasing'],
                    output_min = 65,
                    output_max = 85)
                
                # model
                inps  = tf.keras.Input(shape=(2,))
                calib = combined_calibrators(inps)
                outs  = lattice(calib)

                model = tf.keras.Model(inputs=inps, outputs=outs)
                model.compile(
                    loss = tf.keras.losses.mean_squared_error,
                    optimizer = tf.keras.optimizers.Adam(learning_rate=lr),
                    metrics = [tfa.metrics.RSquare()])

                callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=200)

                hist = model.fit(
                    x = X,
                    y = Y,
                    batch_size = 256,
                    epochs = 200000,
                    shuffle = False,
                    validation_data=(X_t, Y_t),
                    callbacks=[callback],
                    verbose = 0)
                
                a = np.argmax(hist.history['val_r_square'])
                print('n: %3d  -  y_max: %2d  -  grid_size: %3d  -  lr:%6.4f  -  r2: %7.4f' % (n, y_max, grid_size, lr, hist.history['val_r_square'][a]))

                with open('C:/Users/tln229/Downloads/Python/Building/1. Zone subsystem/stat3.txt', 'a') as f:
                    f.write('n: %3d  -  y_max: %2d  -  grid_size: %3d  -  lr:%6.4f  -  r2: %7.4f \n' % (n, y_max, grid_size, lr, hist.history['val_r_square'][a]))
# Out:
# n:  16  -  y_max:  2  -  grid_size:   5  -  lr:0.0010  -  r2: -0.2022
# n:  16  -  y_max:  2  -  grid_size:   5  -  lr:0.0050  -  r2: -0.2024
# n:  16  -  y_max:  2  -  grid_size:   5  -  lr:0.1000  -  r2:  0.6932
# n:  16  -  y_max:  2  -  grid_size:   5  -  lr:0.2000  -  r2:  0.8335
# n:  16  -  y_max:  2  -  grid_size:  10  -  lr:0.0010  -  r2: -0.1845
# n:  16  -  y_max:  2  -  grid_size:  10  -  lr:0.0050  -  r2: -0.1843
# n:  16  -  y_max:  2  -  grid_size:  10  -  lr:0.1000  -  r2:  0.2672
# n:  16  -  y_max:  2  -  grid_size:  10  -  lr:0.2000  -  r2:  0.5600
# n:  16  -  y_max:  2  -  grid_size:  20  -  lr:0.0010  -  r2: -0.1832
# n:  16  -  y_max:  2  -  grid_size:  20  -  lr:0.0050  -  r2: -0.1831
# n:  16  -  y_max:  2  -  grid_size:  20  -  lr:0.1000  -  r2:  0.1376
# n:  16  -  y_max:  2  -  grid_size:  20  -  lr:0.2000  -  r2:  0.5093
# n:  16  -  y_max:  2  -  grid_size:  40  -  lr:0.0010  -  r2: -0.1856
# n:  16  -  y_max:  2  -  grid_size:  40  -  lr:0.0050  -  r2: -0.1875
# n:  16  -  y_max:  2  -  grid_size:  40  -  lr:0.1000  -  r2:  0.3145
# n:  16  -  y_max:  2  -  grid_size:  40  -  lr:0.2000  -  r2: -0.9872
# n:  16  -  y_max:  5  -  grid_size:   5  -  lr:0.0010  -  r2: -0.1637
# n:  16  -  y_max:  5  -  grid_size:   5  -  lr:0.0050  -  r2: -0.1653
# n:  16  -  y_max:  5  -  grid_size:   5  -  lr:0.1000  -  r2: -0.1666
# n:  16  -  y_max:  5  -  grid_size:   5  -  lr:0.2000  -  r2: -0.3209
# n:  16  -  y_max:  5  -  grid_size:  10  -  lr:0.0010  -  r2: -0.1574
# n:  16  -  y_max:  5  -  grid_size:  10  -  lr:0.0050  -  r2: -0.1587
# n:  16  -  y_max:  5  -  grid_size:  10  -  lr:0.1000  -  r2: -0.1925
# n:  16  -  y_max:  5  -  grid_size:  10  -  lr:0.2000  -  r2: -0.0234
# n:  16  -  y_max:  5  -  grid_size:  20  -  lr:0.0010  -  r2: -0.1669
# n:  16  -  y_max:  5  -  grid_size:  20  -  lr:0.0050  -  r2: -0.1675
# n:  16  -  y_max:  5  -  grid_size:  20  -  lr:0.1000  -  r2: -0.2106
# n:  16  -  y_max:  5  -  grid_size:  20  -  lr:0.2000  -  r2: -0.0121
# n:  16  -  y_max:  5  -  grid_size:  40  -  lr:0.0010  -  r2: -0.1764
# n:  16  -  y_max:  5  -  grid_size:  40  -  lr:0.0050  -  r2: -0.1776
# n:  16  -  y_max:  5  -  grid_size:  40  -  lr:0.1000  -  r2: -0.0027
# n:  16  -  y_max:  5  -  grid_size:  40  -  lr:0.2000  -  r2:  0.2815
# n:  16  -  y_max: 10  -  grid_size:   5  -  lr:0.0010  -  r2: -0.1218
# n:  16  -  y_max: 10  -  grid_size:   5  -  lr:0.0050  -  r2: -0.1438
# n:  16  -  y_max: 10  -  grid_size:   5  -  lr:0.1000  -  r2: -0.1593
# n:  16  -  y_max: 10  -  grid_size:   5  -  lr:0.2000  -  r2: -0.1593
# n:  16  -  y_max: 10  -  grid_size:  10  -  lr:0.0010  -  r2: -0.1302
# n:  16  -  y_max: 10  -  grid_size:  10  -  lr:0.0050  -  r2: -0.1460
# n:  16  -  y_max: 10  -  grid_size:  10  -  lr:0.1000  -  r2: -0.1612
# n:  16  -  y_max: 10  -  grid_size:  10  -  lr:0.2000  -  r2: -0.1947
# n:  16  -  y_max: 10  -  grid_size:  20  -  lr:0.0010  -  r2: -0.1530
# n:  16  -  y_max: 10  -  grid_size:  20  -  lr:0.0050  -  r2: -0.1614
# n:  16  -  y_max: 10  -  grid_size:  20  -  lr:0.1000  -  r2: -0.1752
# n:  16  -  y_max: 10  -  grid_size:  20  -  lr:0.2000  -  r2: -0.0415
# n:  16  -  y_max: 10  -  grid_size:  40  -  lr:0.0010  -  r2: -0.1703
# n:  16  -  y_max: 10  -  grid_size:  40  -  lr:0.0050  -  r2: -0.1736
# n:  16  -  y_max: 10  -  grid_size:  40  -  lr:0.1000  -  r2: -0.1220
# n:  16  -  y_max: 10  -  grid_size:  40  -  lr:0.2000  -  r2:  0.0314
# n:  16  -  y_max: 20  -  grid_size:   5  -  lr:0.0010  -  r2: -0.0831
# n:  16  -  y_max: 20  -  grid_size:   5  -  lr:0.0050  -  r2: -0.0988
# n:  16  -  y_max: 20  -  grid_size:   5  -  lr:0.1000  -  r2: -0.1374
# n:  16  -  y_max: 20  -  grid_size:   5  -  lr:0.2000  -  r2: -0.1435
# n:  16  -  y_max: 20  -  grid_size:  10  -  lr:0.0010  -  r2: -0.1007
# n:  16  -  y_max: 20  -  grid_size:  10  -  lr:0.0050  -  r2: -0.1205
# n:  16  -  y_max: 20  -  grid_size:  10  -  lr:0.1000  -  r2: -0.1446
# n:  16  -  y_max: 20  -  grid_size:  10  -  lr:0.2000  -  r2: -0.1483
# n:  16  -  y_max: 20  -  grid_size:  20  -  lr:0.0010  -  r2: -0.1344
# n:  16  -  y_max: 20  -  grid_size:  20  -  lr:0.0050  -  r2: -0.1491
# n:  16  -  y_max: 20  -  grid_size:  20  -  lr:0.1000  -  r2: -0.1642
# n:  16  -  y_max: 20  -  grid_size:  20  -  lr:0.2000  -  r2: -0.1703
# n:  16  -  y_max: 20  -  grid_size:  40  -  lr:0.0010  -  r2: -0.1603
# n:  16  -  y_max: 20  -  grid_size:  40  -  lr:0.0050  -  r2: -0.1680
# n:  16  -  y_max: 20  -  grid_size:  40  -  lr:0.1000  -  r2: -0.1741
# n:  16  -  y_max: 20  -  grid_size:  40  -  lr:0.2000  -  r2:  0.2231
# n:  32  -  y_max:  2  -  grid_size:   5  -  lr:0.0010  -  r2:  0.9972
# n:  32  -  y_max:  2  -  grid_size:   5  -  lr:0.0050  -  r2:  0.9972
# n:  32  -  y_max:  2  -  grid_size:   5  -  lr:0.1000  -  r2:  0.9971
# n:  32  -  y_max:  2  -  grid_size:   5  -  lr:0.2000  -  r2:  0.9972
# n:  32  -  y_max:  2  -  grid_size:  10  -  lr:0.0010  -  r2:  0.8239
# n:  32  -  y_max:  2  -  grid_size:  10  -  lr:0.0050  -  r2:  0.8263
# n:  32  -  y_max:  2  -  grid_size:  10  -  lr:0.1000  -  r2:  0.8992
# n:  32  -  y_max:  2  -  grid_size:  10  -  lr:0.2000  -  r2:  0.9252
# n:  32  -  y_max:  2  -  grid_size:  20  -  lr:0.0010  -  r2:  0.8302
# n:  32  -  y_max:  2  -  grid_size:  20  -  lr:0.0050  -  r2:  0.8634
# n:  32  -  y_max:  2  -  grid_size:  20  -  lr:0.1000  -  r2:  0.9136
# n:  32  -  y_max:  2  -  grid_size:  20  -  lr:0.2000  -  r2:  0.7605
# n:  32  -  y_max:  2  -  grid_size:  40  -  lr:0.0010  -  r2:  0.7799
# n:  32  -  y_max:  2  -  grid_size:  40  -  lr:0.0050  -  r2:  0.8401
# n:  32  -  y_max:  2  -  grid_size:  40  -  lr:0.1000  -  r2:  0.7930
# n:  32  -  y_max:  2  -  grid_size:  40  -  lr:0.2000  -  r2: -0.0000
# n:  32  -  y_max:  5  -  grid_size:   5  -  lr:0.0010  -  r2:  0.9255
# n:  32  -  y_max:  5  -  grid_size:   5  -  lr:0.0050  -  r2:  0.9672
# n:  32  -  y_max:  5  -  grid_size:   5  -  lr:0.1000  -  r2:  0.9387
# n:  32  -  y_max:  5  -  grid_size:   5  -  lr:0.2000  -  r2:  0.9773
# n:  32  -  y_max:  5  -  grid_size:  10  -  lr:0.0010  -  r2:  0.9102
# n:  32  -  y_max:  5  -  grid_size:  10  -  lr:0.0050  -  r2:  0.8977
# n:  32  -  y_max:  5  -  grid_size:  10  -  lr:0.1000  -  r2:  0.8682
# n:  32  -  y_max:  5  -  grid_size:  10  -  lr:0.2000  -  r2:  0.9780
# n:  32  -  y_max:  5  -  grid_size:  20  -  lr:0.0010  -  r2:  0.8671
# n:  32  -  y_max:  5  -  grid_size:  20  -  lr:0.0050  -  r2:  0.8242
# n:  32  -  y_max:  5  -  grid_size:  20  -  lr:0.1000  -  r2:  0.9490
# n:  32  -  y_max:  5  -  grid_size:  20  -  lr:0.2000  -  r2:  0.9689
# n:  32  -  y_max:  5  -  grid_size:  40  -  lr:0.0010  -  r2:  0.7692
# n:  32  -  y_max:  5  -  grid_size:  40  -  lr:0.0050  -  r2:  0.8059
# n:  32  -  y_max:  5  -  grid_size:  40  -  lr:0.1000  -  r2:  0.9520
# n:  32  -  y_max:  5  -  grid_size:  40  -  lr:0.2000  -  r2:  0.9840
# n:  32  -  y_max: 10  -  grid_size:   5  -  lr:0.0010  -  r2:  0.9008
# n:  32  -  y_max: 10  -  grid_size:   5  -  lr:0.0050  -  r2:  0.8892
# n:  32  -  y_max: 10  -  grid_size:   5  -  lr:0.1000  -  r2:  0.9538
# n:  32  -  y_max: 10  -  grid_size:   5  -  lr:0.2000  -  r2:  0.9488
# n:  32  -  y_max: 10  -  grid_size:  10  -  lr:0.0010  -  r2:  0.8389
# n:  32  -  y_max: 10  -  grid_size:  10  -  lr:0.0050  -  r2:  0.8468
# n:  32  -  y_max: 10  -  grid_size:  10  -  lr:0.1000  -  r2:  0.8363
# n:  32  -  y_max: 10  -  grid_size:  10  -  lr:0.2000  -  r2:  0.8545
# n:  32  -  y_max: 10  -  grid_size:  20  -  lr:0.0010  -  r2:  0.8409
# n:  32  -  y_max: 10  -  grid_size:  20  -  lr:0.0050  -  r2:  0.8248
# n:  32  -  y_max: 10  -  grid_size:  20  -  lr:0.1000  -  r2:  0.8727
# n:  32  -  y_max: 10  -  grid_size:  20  -  lr:0.2000  -  r2:  0.9518
# n:  32  -  y_max: 10  -  grid_size:  40  -  lr:0.0010  -  r2:  0.7661
# n:  32  -  y_max: 10  -  grid_size:  40  -  lr:0.0050  -  r2:  0.7695
# n:  32  -  y_max: 10  -  grid_size:  40  -  lr:0.1000  -  r2:  0.9645
# n:  32  -  y_max: 10  -  grid_size:  40  -  lr:0.2000  -  r2:  0.9779
# n:  32  -  y_max: 20  -  grid_size:   5  -  lr:0.0010  -  r2:  0.7969
# n:  32  -  y_max: 20  -  grid_size:   5  -  lr:0.0050  -  r2:  0.8363
# n:  32  -  y_max: 20  -  grid_size:   5  -  lr:0.1000  -  r2:  0.8469
# n:  32  -  y_max: 20  -  grid_size:   5  -  lr:0.2000  -  r2:  0.9383
# n:  32  -  y_max: 20  -  grid_size:  10  -  lr:0.0010  -  r2:  0.7679
# n:  32  -  y_max: 20  -  grid_size:  10  -  lr:0.0050  -  r2:  0.7728
# n:  32  -  y_max: 20  -  grid_size:  10  -  lr:0.1000  -  r2:  0.7163
# n:  32  -  y_max: 20  -  grid_size:  10  -  lr:0.2000  -  r2:  0.7431
# n:  32  -  y_max: 20  -  grid_size:  20  -  lr:0.0010  -  r2:  0.7790
# n:  32  -  y_max: 20  -  grid_size:  20  -  lr:0.0050  -  r2:  0.8880
# n:  32  -  y_max: 20  -  grid_size:  20  -  lr:0.1000  -  r2:  0.8226
# n:  32  -  y_max: 20  -  grid_size:  20  -  lr:0.2000  -  r2:  0.8458
# n:  32  -  y_max: 20  -  grid_size:  40  -  lr:0.0010  -  r2:  0.7253
# n:  32  -  y_max: 20  -  grid_size:  40  -  lr:0.0050  -  r2:  0.7164
# n:  32  -  y_max: 20  -  grid_size:  40  -  lr:0.1000  -  r2:  0.9111
# n:  32  -  y_max: 20  -  grid_size:  40  -  lr:0.2000  -  r2:  0.9442
# n:  64  -  y_max:  2  -  grid_size:   5  -  lr:0.0010  -  r2:  0.9983
# n:  64  -  y_max:  2  -  grid_size:   5  -  lr:0.0050  -  r2:  0.9983
# n:  64  -  y_max:  2  -  grid_size:   5  -  lr:0.1000  -  r2:  0.9983
# n:  64  -  y_max:  2  -  grid_size:   5  -  lr:0.2000  -  r2:  0.9980
# n:  64  -  y_max:  2  -  grid_size:  10  -  lr:0.0010  -  r2:  0.9927
# n:  64  -  y_max:  2  -  grid_size:  10  -  lr:0.0050  -  r2:  0.9929
# n:  64  -  y_max:  2  -  grid_size:  10  -  lr:0.1000  -  r2:  0.9886
# n:  64  -  y_max:  2  -  grid_size:  10  -  lr:0.2000  -  r2:  0.0297
# n:  64  -  y_max:  2  -  grid_size:  20  -  lr:0.0010  -  r2:  0.9889
# n:  64  -  y_max:  2  -  grid_size:  20  -  lr:0.0050  -  r2:  0.9899
# n:  64  -  y_max:  2  -  grid_size:  20  -  lr:0.1000  -  r2:  0.0371
# n:  64  -  y_max:  2  -  grid_size:  20  -  lr:0.2000  -  r2: -0.0019
# n:  64  -  y_max:  2  -  grid_size:  40  -  lr:0.0010  -  r2:  0.9800
# n:  64  -  y_max:  2  -  grid_size:  40  -  lr:0.0050  -  r2:  0.9873
# n:  64  -  y_max:  2  -  grid_size:  40  -  lr:0.1000  -  r2:  0.1655
# n:  64  -  y_max:  2  -  grid_size:  40  -  lr:0.2000  -  r2:  0.0116
# n:  64  -  y_max:  5  -  grid_size:   5  -  lr:0.0010  -  r2:  0.9978
# n:  64  -  y_max:  5  -  grid_size:   5  -  lr:0.0050  -  r2:  0.9977
# n:  64  -  y_max:  5  -  grid_size:   5  -  lr:0.1000  -  r2:  0.9982
# n:  64  -  y_max:  5  -  grid_size:   5  -  lr:0.2000  -  r2:  0.9974
# n:  64  -  y_max:  5  -  grid_size:  10  -  lr:0.0010  -  r2:  0.9762
# n:  64  -  y_max:  5  -  grid_size:  10  -  lr:0.0050  -  r2:  0.9633
# n:  64  -  y_max:  5  -  grid_size:  10  -  lr:0.1000  -  r2:  0.9950
# n:  64  -  y_max:  5  -  grid_size:  10  -  lr:0.2000  -  r2:  0.9949
# n:  64  -  y_max:  5  -  grid_size:  20  -  lr:0.0010  -  r2:  0.9371
# n:  64  -  y_max:  5  -  grid_size:  20  -  lr:0.0050  -  r2:  0.9641
# n:  64  -  y_max:  5  -  grid_size:  20  -  lr:0.1000  -  r2:  0.9958
# n:  64  -  y_max:  5  -  grid_size:  20  -  lr:0.2000  -  r2:  0.9548
# n:  64  -  y_max:  5  -  grid_size:  40  -  lr:0.0010  -  r2:  0.9556
# n:  64  -  y_max:  5  -  grid_size:  40  -  lr:0.0050  -  r2:  0.9752
# n:  64  -  y_max:  5  -  grid_size:  40  -  lr:0.1000  -  r2:  0.9921
# n:  64  -  y_max:  5  -  grid_size:  40  -  lr:0.2000  -  r2:  0.1426
# n:  64  -  y_max: 10  -  grid_size:   5  -  lr:0.0010  -  r2:  0.8521
# n:  64  -  y_max: 10  -  grid_size:   5  -  lr:0.0050  -  r2:  0.9224
# n:  64  -  y_max: 10  -  grid_size:   5  -  lr:0.1000  -  r2:  0.9784
# n:  64  -  y_max: 10  -  grid_size:   5  -  lr:0.2000  -  r2:  0.9832
# n:  64  -  y_max: 10  -  grid_size:  10  -  lr:0.0010  -  r2:  0.9662
# n:  64  -  y_max: 10  -  grid_size:  10  -  lr:0.0050  -  r2:  0.9808
# n:  64  -  y_max: 10  -  grid_size:  10  -  lr:0.1000  -  r2:  0.8990
# n:  64  -  y_max: 10  -  grid_size:  10  -  lr:0.2000  -  r2:  0.9959
# n:  64  -  y_max: 10  -  grid_size:  20  -  lr:0.0010  -  r2:  0.9706
# n:  64  -  y_max: 10  -  grid_size:  20  -  lr:0.0050  -  r2:  0.8605
# n:  64  -  y_max: 10  -  grid_size:  20  -  lr:0.1000  -  r2:  0.9942
# n:  64  -  y_max: 10  -  grid_size:  20  -  lr:0.2000  -  r2:  0.9951
# n:  64  -  y_max: 10  -  grid_size:  40  -  lr:0.0010  -  r2:  0.9266
# n:  64  -  y_max: 10  -  grid_size:  40  -  lr:0.0050  -  r2:  0.9146
# n:  64  -  y_max: 10  -  grid_size:  40  -  lr:0.1000  -  r2:  0.9958
# n:  64  -  y_max: 10  -  grid_size:  40  -  lr:0.2000  -  r2:  0.9907
# n:  64  -  y_max: 20  -  grid_size:   5  -  lr:0.0010  -  r2:  0.6528
# n:  64  -  y_max: 20  -  grid_size:   5  -  lr:0.0050  -  r2:  0.8762
# n:  64  -  y_max: 20  -  grid_size:   5  -  lr:0.1000  -  r2:  0.9201
# n:  64  -  y_max: 20  -  grid_size:   5  -  lr:0.2000  -  r2:  0.9022
# n:  64  -  y_max: 20  -  grid_size:  10  -  lr:0.0010  -  r2:  0.6583
# n:  64  -  y_max: 20  -  grid_size:  10  -  lr:0.0050  -  r2:  0.7562
# n:  64  -  y_max: 20  -  grid_size:  10  -  lr:0.1000  -  r2:  0.9541
# n:  64  -  y_max: 20  -  grid_size:  10  -  lr:0.2000  -  r2:  0.8825
# n:  64  -  y_max: 20  -  grid_size:  20  -  lr:0.0010  -  r2:  0.7358
# n:  64  -  y_max: 20  -  grid_size:  20  -  lr:0.0050  -  r2:  0.7550
# n:  64  -  y_max: 20  -  grid_size:  20  -  lr:0.1000  -  r2:  0.9348
# n:  64  -  y_max: 20  -  grid_size:  20  -  lr:0.2000  -  r2:  0.9827
# n:  64  -  y_max: 20  -  grid_size:  40  -  lr:0.0010  -  r2:  0.9415
# n:  64  -  y_max: 20  -  grid_size:  40  -  lr:0.0050  -  r2:  0.8274
# n:  64  -  y_max: 20  -  grid_size:  40  -  lr:0.1000  -  r2:  0.9864
# n:  64  -  y_max: 20  -  grid_size:  40  -  lr:0.2000  -  r2:  0.9881
# n: 128  -  y_max:  2  -  grid_size:   5  -  lr:0.0010  -  r2:  0.9982
# n: 128  -  y_max:  2  -  grid_size:   5  -  lr:0.0050  -  r2:  0.9981
# n: 128  -  y_max:  2  -  grid_size:   5  -  lr:0.1000  -  r2:  0.9982
# n: 128  -  y_max:  2  -  grid_size:   5  -  lr:0.2000  -  r2:  0.9975
# n: 128  -  y_max:  2  -  grid_size:  10  -  lr:0.0010  -  r2:  0.9969
# n: 128  -  y_max:  2  -  grid_size:  10  -  lr:0.0050  -  r2:  0.9969
# n: 128  -  y_max:  2  -  grid_size:  10  -  lr:0.1000  -  r2:  0.9932
# n: 128  -  y_max:  2  -  grid_size:  10  -  lr:0.2000  -  r2:  0.3668
# n: 128  -  y_max:  2  -  grid_size:  20  -  lr:0.0010  -  r2:  0.9963
# n: 128  -  y_max:  2  -  grid_size:  20  -  lr:0.0050  -  r2:  0.9963
# n: 128  -  y_max:  2  -  grid_size:  20  -  lr:0.1000  -  r2:  0.3667
# n: 128  -  y_max:  2  -  grid_size:  20  -  lr:0.2000  -  r2:  0.3780
# n: 128  -  y_max:  2  -  grid_size:  40  -  lr:0.0010  -  r2:  0.9936
# n: 128  -  y_max:  2  -  grid_size:  40  -  lr:0.0050  -  r2:  0.9934
# n: 128  -  y_max:  2  -  grid_size:  40  -  lr:0.1000  -  r2:  0.3610
# n: 128  -  y_max:  2  -  grid_size:  40  -  lr:0.2000  -  r2:  0.3596
# n: 128  -  y_max:  5  -  grid_size:   5  -  lr:0.0010  -  r2:  0.9978
# n: 128  -  y_max:  5  -  grid_size:   5  -  lr:0.0050  -  r2:  0.9980
# n: 128  -  y_max:  5  -  grid_size:   5  -  lr:0.1000  -  r2:  0.9979
# n: 128  -  y_max:  5  -  grid_size:   5  -  lr:0.2000  -  r2:  0.9972
# n: 128  -  y_max:  5  -  grid_size:  10  -  lr:0.0010  -  r2:  0.9978
# n: 128  -  y_max:  5  -  grid_size:  10  -  lr:0.0050  -  r2:  0.9977
# n: 128  -  y_max:  5  -  grid_size:  10  -  lr:0.1000  -  r2:  0.9960
# n: 128  -  y_max:  5  -  grid_size:  10  -  lr:0.2000  -  r2:  0.9803
# n: 128  -  y_max:  5  -  grid_size:  20  -  lr:0.0010  -  r2:  0.9939
# n: 128  -  y_max:  5  -  grid_size:  20  -  lr:0.0050  -  r2:  0.9944
# n: 128  -  y_max:  5  -  grid_size:  20  -  lr:0.1000  -  r2:  0.9895
# n: 128  -  y_max:  5  -  grid_size:  20  -  lr:0.2000  -  r2:  0.9770
# n: 128  -  y_max:  5  -  grid_size:  40  -  lr:0.0010  -  r2:  0.9922
# n: 128  -  y_max:  5  -  grid_size:  40  -  lr:0.0050  -  r2:  0.9911
# n: 128  -  y_max:  5  -  grid_size:  40  -  lr:0.1000  -  r2:  0.9892
# n: 128  -  y_max:  5  -  grid_size:  40  -  lr:0.2000  -  r2:  0.3653
# n: 128  -  y_max: 10  -  grid_size:   5  -  lr:0.0010  -  r2:  0.9174
# n: 128  -  y_max: 10  -  grid_size:   5  -  lr:0.0050  -  r2:  0.9172
# n: 128  -  y_max: 10  -  grid_size:   5  -  lr:0.1000  -  r2:  0.9973
# n: 128  -  y_max: 10  -  grid_size:   5  -  lr:0.2000  -  r2:  0.9958
# n: 128  -  y_max: 10  -  grid_size:  10  -  lr:0.0010  -  r2:  0.9926
# n: 128  -  y_max: 10  -  grid_size:  10  -  lr:0.0050  -  r2:  0.9844
# n: 128  -  y_max: 10  -  grid_size:  10  -  lr:0.1000  -  r2:  0.9622
# n: 128  -  y_max: 10  -  grid_size:  10  -  lr:0.2000  -  r2:  0.9867
# n: 128  -  y_max: 10  -  grid_size:  20  -  lr:0.0010  -  r2:  0.9770
# n: 128  -  y_max: 10  -  grid_size:  20  -  lr:0.0050  -  r2:  0.9892
# n: 128  -  y_max: 10  -  grid_size:  20  -  lr:0.1000  -  r2:  0.9631
# n: 128  -  y_max: 10  -  grid_size:  20  -  lr:0.2000  -  r2:  0.9747
# n: 128  -  y_max: 10  -  grid_size:  40  -  lr:0.0010  -  r2:  0.9676
# n: 128  -  y_max: 10  -  grid_size:  40  -  lr:0.0050  -  r2:  0.9810
# n: 128  -  y_max: 10  -  grid_size:  40  -  lr:0.1000  -  r2:  0.9644
# n: 128  -  y_max: 10  -  grid_size:  40  -  lr:0.2000  -  r2:  0.9872
# n: 128  -  y_max: 20  -  grid_size:   5  -  lr:0.0010  -  r2:  0.8352
# n: 128  -  y_max: 20  -  grid_size:   5  -  lr:0.0050  -  r2:  0.8842
# n: 128  -  y_max: 20  -  grid_size:   5  -  lr:0.1000  -  r2:  0.8813
# n: 128  -  y_max: 20  -  grid_size:   5  -  lr:0.2000  -  r2:  0.8973
# n: 128  -  y_max: 20  -  grid_size:  10  -  lr:0.0010  -  r2:  0.9606
# n: 128  -  y_max: 20  -  grid_size:  10  -  lr:0.0050  -  r2:  0.8963
# n: 128  -  y_max: 20  -  grid_size:  10  -  lr:0.1000  -  r2:  0.9557
# n: 128  -  y_max: 20  -  grid_size:  10  -  lr:0.2000  -  r2:  0.9289
# n: 128  -  y_max: 20  -  grid_size:  20  -  lr:0.0010  -  r2:  0.9317
# n: 128  -  y_max: 20  -  grid_size:  20  -  lr:0.0050  -  r2:  0.8747
# n: 128  -  y_max: 20  -  grid_size:  20  -  lr:0.1000  -  r2:  0.9555
# n: 128  -  y_max: 20  -  grid_size:  20  -  lr:0.2000  -  r2:  0.9725
# n: 128  -  y_max: 20  -  grid_size:  40  -  lr:0.0010  -  r2:  0.9083
# n: 128  -  y_max: 20  -  grid_size:  40  -  lr:0.0050  -  r2:  0.8991
# n: 128  -  y_max: 20  -  grid_size:  40  -  lr:0.1000  -  r2:  0.9230
# n: 128  -  y_max: 20  -  grid_size:  40  -  lr:0.2000  -  r2:  0.9139
