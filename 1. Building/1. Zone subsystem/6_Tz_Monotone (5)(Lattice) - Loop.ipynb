# %%
import tensorflow as tf
import tensorflow_addons as tfa
import tensorflow_lattice as tfl
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

np.random.seed(1)

# %%
# DATA
df = pd.read_csv('C:/Users/tln229/Downloads/Python/Building/data/HVAC_B90_102_exp_10m_20210424.csv')

# %%
f = open('C:/Users/tln229/Downloads/Python/Building/1. Zone subsystem/stat.txt', 'w')

for n in ([16, 32, 64, 128]):
    for y_max in ([2, 5, 10, 20]):
        for grid_size in ([3, 10, 20, 50]):
            for lr in ([0.001, 0.005, 0.1, 0.2]):

                n_train = n

                # trainning set
                Tz_k   = np.array(df['room_temp']).reshape(-1,1)[0: n_train]
                Tsa_k1 = np.array(df['supply_discharge_temp']).reshape(-1,1)[1: n_train+1]
                msa_k1 = np.array(df['airflow_current']).reshape(-1,1)[1: n_train+1]
                Tz_k1  = np.array(df['room_temp']).reshape(-1,1)[1: n_train+1]

                X = np.concatenate((Tz_k, Tsa_k1, msa_k1), axis=1)
                Y = np.copy(Tz_k1)

                # test set
                Tz_k_t   = np.array(df['room_temp']).reshape(-1,1)[n_train: 1600]
                Tsa_k1_t = np.array(df['supply_discharge_temp']).reshape(-1,1)[n_train+1: 1600+1]
                msa_k1_t = np.array(df['airflow_current']).reshape(-1,1)[n_train+1: 1600+1]
                Tz_k1_t  = np.array(df['room_temp']).reshape(-1,1)[n_train+1: 1600+1]

                X_t = np.concatenate((Tz_k_t, Tsa_k1_t, msa_k1_t), axis=1)
                Y_t = np.copy(Tz_k1_t)

                # combined calibrator
                combined_calibrators = tfl.layers.ParallelCombination()

                calibrator_x1 = tfl.layers.PWLCalibration(input_keypoints=np.linspace(65,  85,   grid_size), output_min=0, output_max=y_max)
                calibrator_x2 = tfl.layers.PWLCalibration(input_keypoints=np.linspace(50,  100,  grid_size), output_min=0, output_max=y_max, monotonicity='increasing')
                calibrator_x3 = tfl.layers.PWLCalibration(input_keypoints=np.linspace(390, 1010, grid_size), output_min=0, output_max=y_max)

                combined_calibrators.append(calibrator_x1)
                combined_calibrators.append(calibrator_x2)
                combined_calibrators.append(calibrator_x3)

                # Lattice
                lattice = tfl.layers.Lattice(
                    lattice_sizes = [y_max+1, y_max+1, y_max+1],
                    monotonicities = ['increasing', 'increasing', 'increasing'],
                    output_min = 65,
                    output_max = 85)
                
                # model
                inps  = tf.keras.Input(shape=(3,))
                calib = combined_calibrators(inps)
                outs  = lattice(calib)

                model = tf.keras.Model(inputs=inps, outputs=outs)
                model.compile(
                    loss = tf.keras.losses.mean_squared_error,
                    optimizer = tf.keras.optimizers.Adam(learning_rate=lr),
                    metrics = [tfa.metrics.RSquare()])

                callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=200)

                hist = model.fit(
                    x = X,
                    y = Y,
                    batch_size = 256,
                    epochs = 200000,
                    shuffle = False,
                    validation_data=(X_t, Y_t),
                    callbacks=[callback],
                    verbose = 0)
                
                a = np.argmax(hist.history['val_r_square'])
                print('n: %3d  -  y_max: %2d  -  grid_size: %3d  -  lr:%6.4f  -  r2: %7.4f' % (n, y_max, grid_size, lr, hist.history['val_r_square'][a]))

                with open('C:/Users/tln229/Downloads/Python/Building/1. Zone subsystem/stat.txt', 'a') as f:
                    f.write('n: %3d  -  y_max: %2d  -  grid_size: %3d  -  lr:%6.4f  -  r2: %7.4f \n' % (n, y_max, grid_size, lr, hist.history['val_r_square'][a]))
# Out:
# n:  16  -  y_max:  2  -  grid_size:   3  -  lr:0.0010  -  r2: -2.7782
# n:  16  -  y_max:  2  -  grid_size:   3  -  lr:0.0050  -  r2: -2.8260
# n:  16  -  y_max:  2  -  grid_size:   3  -  lr:0.1000  -  r2: -2.8692
# n:  16  -  y_max:  2  -  grid_size:   3  -  lr:0.2000  -  r2: -1.9141
# n:  16  -  y_max:  2  -  grid_size:  10  -  lr:0.0010  -  r2: -2.7892
# n:  16  -  y_max:  2  -  grid_size:  10  -  lr:0.0050  -  r2: -2.8831
# n:  16  -  y_max:  2  -  grid_size:  10  -  lr:0.1000  -  r2: -2.3376
# n:  16  -  y_max:  2  -  grid_size:  10  -  lr:0.2000  -  r2: -0.9651
# n:  16  -  y_max:  2  -  grid_size:  20  -  lr:0.0010  -  r2: -2.8070
# n:  16  -  y_max:  2  -  grid_size:  20  -  lr:0.0050  -  r2: -2.9774
# n:  16  -  y_max:  2  -  grid_size:  20  -  lr:0.1000  -  r2: -1.4572
# n:  16  -  y_max:  2  -  grid_size:  20  -  lr:0.2000  -  r2:  0.3599
# n:  16  -  y_max:  2  -  grid_size:  50  -  lr:0.0010  -  r2: -2.8544
# n:  16  -  y_max:  2  -  grid_size:  50  -  lr:0.0050  -  r2: -3.2441
# n:  16  -  y_max:  2  -  grid_size:  50  -  lr:0.1000  -  r2:  0.5461
# n:  16  -  y_max:  2  -  grid_size:  50  -  lr:0.2000  -  r2:  0.2639
# n:  16  -  y_max:  5  -  grid_size:   3  -  lr:0.0010  -  r2: -2.7708
# n:  16  -  y_max:  5  -  grid_size:   3  -  lr:0.0050  -  r2: -2.7883
# n:  16  -  y_max:  5  -  grid_size:   3  -  lr:0.1000  -  r2: -3.2634
# n:  16  -  y_max:  5  -  grid_size:   3  -  lr:0.2000  -  r2: -3.8869
# n:  16  -  y_max:  5  -  grid_size:  10  -  lr:0.0010  -  r2: -2.7752
# n:  16  -  y_max:  5  -  grid_size:  10  -  lr:0.0050  -  r2: -2.8105
# n:  16  -  y_max:  5  -  grid_size:  10  -  lr:0.1000  -  r2: -3.6786
# n:  16  -  y_max:  5  -  grid_size:  10  -  lr:0.2000  -  r2: -2.8912
# n:  16  -  y_max:  5  -  grid_size:  20  -  lr:0.0010  -  r2: -2.7822
# n:  16  -  y_max:  5  -  grid_size:  20  -  lr:0.0050  -  r2: -2.8466
# n:  16  -  y_max:  5  -  grid_size:  20  -  lr:0.1000  -  r2: -2.6177
# n:  16  -  y_max:  5  -  grid_size:  20  -  lr:0.2000  -  r2: -1.6134
# n:  16  -  y_max:  5  -  grid_size:  50  -  lr:0.0010  -  r2: -2.8009
# n:  16  -  y_max:  5  -  grid_size:  50  -  lr:0.0050  -  r2: -2.9445
# n:  16  -  y_max:  5  -  grid_size:  50  -  lr:0.1000  -  r2: -1.6954
# n:  16  -  y_max:  5  -  grid_size:  50  -  lr:0.2000  -  r2:  0.0738
# n:  16  -  y_max: 10  -  grid_size:   3  -  lr:0.0010  -  r2: -2.7685
# n:  16  -  y_max: 10  -  grid_size:   3  -  lr:0.0050  -  r2: -2.7768
# n:  16  -  y_max: 10  -  grid_size:   3  -  lr:0.1000  -  r2: -2.9911
# n:  16  -  y_max: 10  -  grid_size:   3  -  lr:0.2000  -  r2: -3.2536
# n:  16  -  y_max: 10  -  grid_size:  10  -  lr:0.0010  -  r2: -2.7707
# n:  16  -  y_max: 10  -  grid_size:  10  -  lr:0.0050  -  r2: -2.7878
# n:  16  -  y_max: 10  -  grid_size:  10  -  lr:0.1000  -  r2: -3.2557
# n:  16  -  y_max: 10  -  grid_size:  10  -  lr:0.2000  -  r2: -3.8731
# n:  16  -  y_max: 10  -  grid_size:  20  -  lr:0.0010  -  r2: -2.7742
# n:  16  -  y_max: 10  -  grid_size:  20  -  lr:0.0050  -  r2: -2.8056
# n:  16  -  y_max: 10  -  grid_size:  20  -  lr:0.1000  -  r2: -1.7785
# n:  16  -  y_max: 10  -  grid_size:  20  -  lr:0.2000  -  r2: -2.0387
# n:  16  -  y_max: 10  -  grid_size:  50  -  lr:0.0010  -  r2: -2.7835
# n:  16  -  y_max: 10  -  grid_size:  50  -  lr:0.0050  -  r2: -2.8531
# n:  16  -  y_max: 10  -  grid_size:  50  -  lr:0.1000  -  r2: -2.3558
# n:  16  -  y_max: 10  -  grid_size:  50  -  lr:0.2000  -  r2: -1.5364
# n:  16  -  y_max: 20  -  grid_size:   3  -  lr:0.0010  -  r2: -2.7674
# n:  16  -  y_max: 20  -  grid_size:   3  -  lr:0.0050  -  r2: -2.7712
# n:  16  -  y_max: 20  -  grid_size:   3  -  lr:0.1000  -  r2: -2.8664
# n:  16  -  y_max: 20  -  grid_size:   3  -  lr:0.2000  -  r2: -2.9779
# n:  16  -  y_max: 20  -  grid_size:  10  -  lr:0.0010  -  r2: -2.7685
# n:  16  -  y_max: 20  -  grid_size:  10  -  lr:0.0050  -  r2: -2.7767
# n:  16  -  y_max: 20  -  grid_size:  10  -  lr:0.1000  -  r2: -2.9882
# n:  16  -  y_max: 20  -  grid_size:  10  -  lr:0.2000  -  r2: -3.2470
# n:  16  -  y_max: 20  -  grid_size:  20  -  lr:0.0010  -  r2: -2.7703
# n:  16  -  y_max: 20  -  grid_size:  20  -  lr:0.0050  -  r2: -2.7855
# n:  16  -  y_max: 20  -  grid_size:  20  -  lr:0.1000  -  r2: -3.1934
# n:  16  -  y_max: 20  -  grid_size:  20  -  lr:0.2000  -  r2: -3.7162
# n:  16  -  y_max: 20  -  grid_size:  50  -  lr:0.0010  -  r2: -2.7749
# n:  16  -  y_max: 20  -  grid_size:  50  -  lr:0.0050  -  r2: -2.8089
# n:  16  -  y_max: 20  -  grid_size:  50  -  lr:0.1000  -  r2: -2.7745
# n:  16  -  y_max: 20  -  grid_size:  50  -  lr:0.2000  -  r2: -2.1138
# n:  32  -  y_max:  2  -  grid_size:   3  -  lr:0.0010  -  r2:  0.8591
# n:  32  -  y_max:  2  -  grid_size:   3  -  lr:0.0050  -  r2:  0.8143
# n:  32  -  y_max:  2  -  grid_size:   3  -  lr:0.1000  -  r2:  0.9270
# n:  32  -  y_max:  2  -  grid_size:   3  -  lr:0.2000  -  r2:  0.9554
# n:  32  -  y_max:  2  -  grid_size:  10  -  lr:0.0010  -  r2:  0.8600
# n:  32  -  y_max:  2  -  grid_size:  10  -  lr:0.0050  -  r2:  0.8662
# n:  32  -  y_max:  2  -  grid_size:  10  -  lr:0.1000  -  r2:  0.9168
# n:  32  -  y_max:  2  -  grid_size:  10  -  lr:0.2000  -  r2:  0.8009
# n:  32  -  y_max:  2  -  grid_size:  20  -  lr:0.0010  -  r2:  0.8423
# n:  32  -  y_max:  2  -  grid_size:  20  -  lr:0.0050  -  r2:  0.8431
# n:  32  -  y_max:  2  -  grid_size:  20  -  lr:0.1000  -  r2:  0.7247
# n:  32  -  y_max:  2  -  grid_size:  20  -  lr:0.2000  -  r2:  0.0002
# n:  32  -  y_max:  2  -  grid_size:  50  -  lr:0.0010  -  r2:  0.7985
# n:  32  -  y_max:  2  -  grid_size:  50  -  lr:0.0050  -  r2:  0.7978
# n:  32  -  y_max:  2  -  grid_size:  50  -  lr:0.1000  -  r2:  0.0004
# n:  32  -  y_max:  2  -  grid_size:  50  -  lr:0.2000  -  r2:  0.0004
# n:  32  -  y_max:  5  -  grid_size:   3  -  lr:0.0010  -  r2:  0.7795
# n:  32  -  y_max:  5  -  grid_size:   3  -  lr:0.0050  -  r2:  0.8688
# n:  32  -  y_max:  5  -  grid_size:   3  -  lr:0.1000  -  r2:  0.7949
# n:  32  -  y_max:  5  -  grid_size:   3  -  lr:0.2000  -  r2:  0.8157
# n:  32  -  y_max:  5  -  grid_size:  10  -  lr:0.0010  -  r2:  0.9047
# n:  32  -  y_max:  5  -  grid_size:  10  -  lr:0.0050  -  r2:  0.9113
# n:  32  -  y_max:  5  -  grid_size:  10  -  lr:0.1000  -  r2:  0.8912
# n:  32  -  y_max:  5  -  grid_size:  10  -  lr:0.2000  -  r2:  0.9681
# n:  32  -  y_max:  5  -  grid_size:  20  -  lr:0.0010  -  r2:  0.8940
# n:  32  -  y_max:  5  -  grid_size:  20  -  lr:0.0050  -  r2:  0.8673
# n:  32  -  y_max:  5  -  grid_size:  20  -  lr:0.1000  -  r2:  0.9685
# n:  32  -  y_max:  5  -  grid_size:  20  -  lr:0.2000  -  r2:  0.7846
# n:  32  -  y_max:  5  -  grid_size:  50  -  lr:0.0010  -  r2:  0.8200
# n:  32  -  y_max:  5  -  grid_size:  50  -  lr:0.0050  -  r2:  0.8205
# n:  32  -  y_max:  5  -  grid_size:  50  -  lr:0.1000  -  r2:  0.5462
# n:  32  -  y_max:  5  -  grid_size:  50  -  lr:0.2000  -  r2:  0.0004
# n:  32  -  y_max: 10  -  grid_size:   3  -  lr:0.0010  -  r2:  0.6428
# n:  32  -  y_max: 10  -  grid_size:   3  -  lr:0.0050  -  r2:  0.4953
# n:  32  -  y_max: 10  -  grid_size:   3  -  lr:0.1000  -  r2:  0.9362
# n:  32  -  y_max: 10  -  grid_size:   3  -  lr:0.2000  -  r2:  0.9687
# n:  32  -  y_max: 10  -  grid_size:  10  -  lr:0.0010  -  r2:  0.7953
# n:  32  -  y_max: 10  -  grid_size:  10  -  lr:0.0050  -  r2:  0.8241
# n:  32  -  y_max: 10  -  grid_size:  10  -  lr:0.1000  -  r2:  0.9159
# n:  32  -  y_max: 10  -  grid_size:  10  -  lr:0.2000  -  r2:  0.9272
# n:  32  -  y_max: 10  -  grid_size:  20  -  lr:0.0010  -  r2:  0.8551
# n:  32  -  y_max: 10  -  grid_size:  20  -  lr:0.0050  -  r2:  0.8657
# n:  32  -  y_max: 10  -  grid_size:  20  -  lr:0.1000  -  r2:  0.8866
# n:  32  -  y_max: 10  -  grid_size:  20  -  lr:0.2000  -  r2:  0.9113
# n:  32  -  y_max: 10  -  grid_size:  50  -  lr:0.0010  -  r2:  0.8536
# n:  32  -  y_max: 10  -  grid_size:  50  -  lr:0.0050  -  r2:  0.8012
# n:  32  -  y_max: 10  -  grid_size:  50  -  lr:0.1000  -  r2:  0.8101
# n:  32  -  y_max: 10  -  grid_size:  50  -  lr:0.2000  -  r2:  0.3483
# n:  32  -  y_max: 20  -  grid_size:   3  -  lr:0.0010  -  r2:  0.5886
# n:  32  -  y_max: 20  -  grid_size:   3  -  lr:0.0050  -  r2:  0.8444
# n:  32  -  y_max: 20  -  grid_size:   3  -  lr:0.1000  -  r2:  0.8820
# n:  32  -  y_max: 20  -  grid_size:   3  -  lr:0.2000  -  r2:  0.8402
# n:  32  -  y_max: 20  -  grid_size:  10  -  lr:0.0010  -  r2:  0.8395
# n:  32  -  y_max: 20  -  grid_size:  10  -  lr:0.0050  -  r2:  0.7708
# n:  32  -  y_max: 20  -  grid_size:  10  -  lr:0.1000  -  r2:  0.9057
# n:  32  -  y_max: 20  -  grid_size:  10  -  lr:0.2000  -  r2:  0.6914
# n:  32  -  y_max: 20  -  grid_size:  20  -  lr:0.0010  -  r2:  0.8173
# n:  32  -  y_max: 20  -  grid_size:  20  -  lr:0.0050  -  r2:  0.8161
# n:  32  -  y_max: 20  -  grid_size:  20  -  lr:0.1000  -  r2:  0.7256
# n:  32  -  y_max: 20  -  grid_size:  20  -  lr:0.2000  -  r2:  0.9047
# n:  32  -  y_max: 20  -  grid_size:  50  -  lr:0.0010  -  r2:  0.8352
# n:  32  -  y_max: 20  -  grid_size:  50  -  lr:0.0050  -  r2:  0.8658
# n:  32  -  y_max: 20  -  grid_size:  50  -  lr:0.1000  -  r2:  0.8726
# n:  32  -  y_max: 20  -  grid_size:  50  -  lr:0.2000  -  r2:  0.8146
# n:  64  -  y_max:  2  -  grid_size:   3  -  lr:0.0010  -  r2:  0.1002
# n:  64  -  y_max:  2  -  grid_size:   3  -  lr:0.0050  -  r2:  0.0839
# n:  64  -  y_max:  2  -  grid_size:   3  -  lr:0.1000  -  r2:  0.9981
# n:  64  -  y_max:  2  -  grid_size:   3  -  lr:0.2000  -  r2:  0.9979
# n:  64  -  y_max:  2  -  grid_size:  10  -  lr:0.0010  -  r2:  0.6569
# n:  64  -  y_max:  2  -  grid_size:  10  -  lr:0.0050  -  r2:  0.5806
# n:  64  -  y_max:  2  -  grid_size:  10  -  lr:0.1000  -  r2:  0.9206
# n:  64  -  y_max:  2  -  grid_size:  10  -  lr:0.2000  -  r2:  0.9787
# n:  64  -  y_max:  2  -  grid_size:  20  -  lr:0.0010  -  r2:  0.6752
# n:  64  -  y_max:  2  -  grid_size:  20  -  lr:0.0050  -  r2:  0.6484
# n:  64  -  y_max:  2  -  grid_size:  20  -  lr:0.1000  -  r2:  0.9463
# n:  64  -  y_max:  2  -  grid_size:  20  -  lr:0.2000  -  r2:  0.7613
# n:  64  -  y_max:  2  -  grid_size:  50  -  lr:0.0010  -  r2:  0.3458
# n:  64  -  y_max:  2  -  grid_size:  50  -  lr:0.0050  -  r2:  0.3838
# n:  64  -  y_max:  2  -  grid_size:  50  -  lr:0.1000  -  r2:  0.6229
# n:  64  -  y_max:  2  -  grid_size:  50  -  lr:0.2000  -  r2:  0.8304
# n:  64  -  y_max:  5  -  grid_size:   3  -  lr:0.0010  -  r2:  0.3933
# n:  64  -  y_max:  5  -  grid_size:   3  -  lr:0.0050  -  r2:  0.3975
# n:  64  -  y_max:  5  -  grid_size:   3  -  lr:0.1000  -  r2:  0.9974
# n:  64  -  y_max:  5  -  grid_size:   3  -  lr:0.2000  -  r2:  0.9982
# n:  64  -  y_max:  5  -  grid_size:  10  -  lr:0.0010  -  r2:  0.0326
# n:  64  -  y_max:  5  -  grid_size:  10  -  lr:0.0050  -  r2:  0.7585
# n:  64  -  y_max:  5  -  grid_size:  10  -  lr:0.1000  -  r2:  0.9911
# n:  64  -  y_max:  5  -  grid_size:  10  -  lr:0.2000  -  r2:  0.9591
# n:  64  -  y_max:  5  -  grid_size:  20  -  lr:0.0010  -  r2:  0.9230
# n:  64  -  y_max:  5  -  grid_size:  20  -  lr:0.0050  -  r2:  0.9484
# n:  64  -  y_max:  5  -  grid_size:  20  -  lr:0.1000  -  r2:  0.9771
# n:  64  -  y_max:  5  -  grid_size:  20  -  lr:0.2000  -  r2:  0.9573
# n:  64  -  y_max:  5  -  grid_size:  50  -  lr:0.0010  -  r2:  0.8470
# n:  64  -  y_max:  5  -  grid_size:  50  -  lr:0.0050  -  r2:  0.9301
# n:  64  -  y_max:  5  -  grid_size:  50  -  lr:0.1000  -  r2: -0.0003
# n:  64  -  y_max:  5  -  grid_size:  50  -  lr:0.2000  -  r2:  0.0001
# n:  64  -  y_max: 10  -  grid_size:   3  -  lr:0.0010  -  r2:  0.5545
# n:  64  -  y_max: 10  -  grid_size:   3  -  lr:0.0050  -  r2:  0.5714
# n:  64  -  y_max: 10  -  grid_size:   3  -  lr:0.1000  -  r2:  0.3516
# n:  64  -  y_max: 10  -  grid_size:   3  -  lr:0.2000  -  r2:  0.9920
# n:  64  -  y_max: 10  -  grid_size:  10  -  lr:0.0010  -  r2:  0.4061
# n:  64  -  y_max: 10  -  grid_size:  10  -  lr:0.0050  -  r2:  0.4012
# n:  64  -  y_max: 10  -  grid_size:  10  -  lr:0.1000  -  r2:  0.9891
# n:  64  -  y_max: 10  -  grid_size:  10  -  lr:0.2000  -  r2:  0.0149
# n:  64  -  y_max: 10  -  grid_size:  20  -  lr:0.0010  -  r2:  0.9663
# n:  64  -  y_max: 10  -  grid_size:  20  -  lr:0.0050  -  r2:  0.8726
# n:  64  -  y_max: 10  -  grid_size:  20  -  lr:0.1000  -  r2:  0.9902
# n:  64  -  y_max: 10  -  grid_size:  20  -  lr:0.2000  -  r2:  0.9708
# n:  64  -  y_max: 10  -  grid_size:  50  -  lr:0.0010  -  r2:  0.8424
# n:  64  -  y_max: 10  -  grid_size:  50  -  lr:0.0050  -  r2:  0.8774
# n:  64  -  y_max: 10  -  grid_size:  50  -  lr:0.1000  -  r2:  0.9386
# n:  64  -  y_max: 10  -  grid_size:  50  -  lr:0.2000  -  r2: -0.3782
# n:  64  -  y_max: 20  -  grid_size:   3  -  lr:0.0010  -  r2:  0.6959
# n:  64  -  y_max: 20  -  grid_size:   3  -  lr:0.0050  -  r2:  0.9209
# n:  64  -  y_max: 20  -  grid_size:   3  -  lr:0.1000  -  r2:  0.9964
# n:  64  -  y_max: 20  -  grid_size:   3  -  lr:0.2000  -  r2:  0.9970
# n:  64  -  y_max: 20  -  grid_size:  10  -  lr:0.0010  -  r2:  0.5457
# n:  64  -  y_max: 20  -  grid_size:  10  -  lr:0.0050  -  r2:  0.6716
# n:  64  -  y_max: 20  -  grid_size:  10  -  lr:0.1000  -  r2:  0.9578
# n:  64  -  y_max: 20  -  grid_size:  10  -  lr:0.2000  -  r2:  0.8929
# n:  64  -  y_max: 20  -  grid_size:  20  -  lr:0.0010  -  r2:  0.9255
# n:  64  -  y_max: 20  -  grid_size:  20  -  lr:0.0050  -  r2:  0.9379
# n:  64  -  y_max: 20  -  grid_size:  20  -  lr:0.1000  -  r2:  0.9924
# n:  64  -  y_max: 20  -  grid_size:  20  -  lr:0.2000  -  r2:  0.9810
# n:  64  -  y_max: 20  -  grid_size:  50  -  lr:0.0010  -  r2:  0.6370
# n:  64  -  y_max: 20  -  grid_size:  50  -  lr:0.0050  -  r2:  0.7925
# n:  64  -  y_max: 20  -  grid_size:  50  -  lr:0.1000  -  r2:  0.9736
# n:  64  -  y_max: 20  -  grid_size:  50  -  lr:0.2000  -  r2:  0.9093
# n: 128  -  y_max:  2  -  grid_size:   3  -  lr:0.0010  -  r2:  0.9982
# n: 128  -  y_max:  2  -  grid_size:   3  -  lr:0.0050  -  r2:  0.9980
# n: 128  -  y_max:  2  -  grid_size:   3  -  lr:0.1000  -  r2:  0.9980
# n: 128  -  y_max:  2  -  grid_size:   3  -  lr:0.2000  -  r2:  0.9984
# n: 128  -  y_max:  2  -  grid_size:  10  -  lr:0.0010  -  r2:  0.8138
# n: 128  -  y_max:  2  -  grid_size:  10  -  lr:0.0050  -  r2:  0.8429
# n: 128  -  y_max:  2  -  grid_size:  10  -  lr:0.1000  -  r2:  0.8388
# n: 128  -  y_max:  2  -  grid_size:  10  -  lr:0.2000  -  r2:  0.6427
# n: 128  -  y_max:  2  -  grid_size:  20  -  lr:0.0010  -  r2:  0.8776
# n: 128  -  y_max:  2  -  grid_size:  20  -  lr:0.0050  -  r2:  0.8327
# n: 128  -  y_max:  2  -  grid_size:  20  -  lr:0.1000  -  r2:  0.9695
# n: 128  -  y_max:  2  -  grid_size:  20  -  lr:0.2000  -  r2:  0.4753
# n: 128  -  y_max:  2  -  grid_size:  50  -  lr:0.0010  -  r2:  0.6018
# n: 128  -  y_max:  2  -  grid_size:  50  -  lr:0.0050  -  r2:  0.6661
# n: 128  -  y_max:  2  -  grid_size:  50  -  lr:0.1000  -  r2:  0.4891
# n: 128  -  y_max:  2  -  grid_size:  50  -  lr:0.2000  -  r2:  0.4417
# n: 128  -  y_max:  5  -  grid_size:   3  -  lr:0.0010  -  r2:  0.4472
# n: 128  -  y_max:  5  -  grid_size:   3  -  lr:0.0050  -  r2:  0.5155
# n: 128  -  y_max:  5  -  grid_size:   3  -  lr:0.1000  -  r2:  0.9959
# n: 128  -  y_max:  5  -  grid_size:   3  -  lr:0.2000  -  r2:  0.9977
# n: 128  -  y_max:  5  -  grid_size:  10  -  lr:0.0010  -  r2:  0.5959
# n: 128  -  y_max:  5  -  grid_size:  10  -  lr:0.0050  -  r2:  0.6111
# n: 128  -  y_max:  5  -  grid_size:  10  -  lr:0.1000  -  r2:  0.8621
# n: 128  -  y_max:  5  -  grid_size:  10  -  lr:0.2000  -  r2:  0.9961
# n: 128  -  y_max:  5  -  grid_size:  20  -  lr:0.0010  -  r2:  0.6873
# n: 128  -  y_max:  5  -  grid_size:  20  -  lr:0.0050  -  r2:  0.6897
# n: 128  -  y_max:  5  -  grid_size:  20  -  lr:0.1000  -  r2:  0.9925
# n: 128  -  y_max:  5  -  grid_size:  20  -  lr:0.2000  -  r2:  0.9829
# n: 128  -  y_max:  5  -  grid_size:  50  -  lr:0.0010  -  r2:  0.9861
# n: 128  -  y_max:  5  -  grid_size:  50  -  lr:0.0050  -  r2:  0.9903
# n: 128  -  y_max:  5  -  grid_size:  50  -  lr:0.1000  -  r2: -0.3862
# n: 128  -  y_max:  5  -  grid_size:  50  -  lr:0.2000  -  r2: -0.1784
# n: 128  -  y_max: 10  -  grid_size:   3  -  lr:0.0010  -  r2:  0.8045
# n: 128  -  y_max: 10  -  grid_size:   3  -  lr:0.0050  -  r2:  0.8256
# n: 128  -  y_max: 10  -  grid_size:   3  -  lr:0.1000  -  r2:  0.9932
# n: 128  -  y_max: 10  -  grid_size:   3  -  lr:0.2000  -  r2:  0.9959
# n: 128  -  y_max: 10  -  grid_size:  10  -  lr:0.0010  -  r2:  0.6713
# n: 128  -  y_max: 10  -  grid_size:  10  -  lr:0.0050  -  r2:  0.7253
# n: 128  -  y_max: 10  -  grid_size:  10  -  lr:0.1000  -  r2:  0.9956
# n: 128  -  y_max: 10  -  grid_size:  10  -  lr:0.2000  -  r2:  0.9873
# n: 128  -  y_max: 10  -  grid_size:  20  -  lr:0.0010  -  r2:  0.9493
# n: 128  -  y_max: 10  -  grid_size:  20  -  lr:0.0050  -  r2:  0.9229
# n: 128  -  y_max: 10  -  grid_size:  20  -  lr:0.1000  -  r2:  0.9912
# n: 128  -  y_max: 10  -  grid_size:  20  -  lr:0.2000  -  r2:  0.9859
# n: 128  -  y_max: 10  -  grid_size:  50  -  lr:0.0010  -  r2:  0.9508
# n: 128  -  y_max: 10  -  grid_size:  50  -  lr:0.0050  -  r2:  0.9389
# n: 128  -  y_max: 10  -  grid_size:  50  -  lr:0.1000  -  r2:  0.9410
# n: 128  -  y_max: 10  -  grid_size:  50  -  lr:0.2000  -  r2: -0.3547
# n: 128  -  y_max: 20  -  grid_size:   3  -  lr:0.0010  -  r2:  0.7441
# n: 128  -  y_max: 20  -  grid_size:   3  -  lr:0.0050  -  r2:  0.7337
# n: 128  -  y_max: 20  -  grid_size:   3  -  lr:0.1000  -  r2:  0.8235
# n: 128  -  y_max: 20  -  grid_size:   3  -  lr:0.2000  -  r2:  0.9930
# n: 128  -  y_max: 20  -  grid_size:  10  -  lr:0.0010  -  r2:  0.6690
# n: 128  -  y_max: 20  -  grid_size:  10  -  lr:0.0050  -  r2:  0.7313
# n: 128  -  y_max: 20  -  grid_size:  10  -  lr:0.1000  -  r2:  0.9592
# n: 128  -  y_max: 20  -  grid_size:  10  -  lr:0.2000  -  r2:  0.9466
# n: 128  -  y_max: 20  -  grid_size:  20  -  lr:0.0010  -  r2:  0.9750
# n: 128  -  y_max: 20  -  grid_size:  20  -  lr:0.0050  -  r2:  0.8867
# n: 128  -  y_max: 20  -  grid_size:  20  -  lr:0.1000  -  r2:  0.9784
# n: 128  -  y_max: 20  -  grid_size:  20  -  lr:0.2000  -  r2:  0.9913
# n: 128  -  y_max: 20  -  grid_size:  50  -  lr:0.0010  -  r2:  0.8542
# n: 128  -  y_max: 20  -  grid_size:  50  -  lr:0.0050  -  r2:  0.8707
# n: 128  -  y_max: 20  -  grid_size:  50  -  lr:0.1000  -  r2:  0.9060
# n: 128  -  y_max: 20  -  grid_size:  50  -  lr:0.2000  -  r2:  0.9254
