# %%
# library
import torch
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.metrics import r2_score

torch.manual_seed(1)
np.random.seed(1)
torch.set_printoptions(precision=3)

# %%
# Model
class Net(torch.nn.Module):
    def __init__(self, s):
        super(Net, self).__init__()
        self.input   = torch.nn.Linear(3, s)
        self.output  = torch.nn.Linear(s, 1)

    def forward(self, x):
        z = torch.tanh(self.input(x))
        z = self.output(z)
        z = torch.relu(100 - torch.relu(z))
        return z

# %%
# Model error
def eval(model, testset, p):
    with torch.no_grad():
        pred_Y = model(testset.x_data)
    
    # R^2 qrh
    r2_qrh = r2_score(testset.y_data, pred_Y)

    # R^2 msa
    pred_msa = pred_Y*p[0] + p[1]
    r2_msa = r2_score(testset.msa_data, pred_msa)
    
    return r2_qrh, r2_msa

# %%
# Data
class Data(torch.utils.data.Dataset):
  def __init__(self, src_file, start=None, end=None):
    df = pd.read_csv(src_file)
    clg_sp       = np.array(df['clg_sp_current']).reshape(-1,1)[start: end]
    htg_sp       = np.array(df['htg_sp_current']).reshape(-1,1)[start: end]
    htg_clg_mode = 1*np.array(df['htg_clg_mode']).reshape(-1,1)[start: end]

    sp_k   = htg_sp*htg_clg_mode + clg_sp*(1-htg_clg_mode)
    Tz_k   = np.array(df['thermostat_room_temp']).reshape(-1,1)[start: end]
    qrh_k  = np.array(df['htg_valve_command']).reshape(-1,1)[start: end]
    qrh_k1 = np.array(df['htg_valve_command']).reshape(-1,1)[start+1: end+1]
    msa_k1 = np.array(df['airflow_desired']).reshape(-1,1)[start+1: end+1]
    tmp_x  = np.concatenate((sp_k, Tz_k, qrh_k), axis=1)
    
    self.x_data   = torch.tensor(tmp_x,  dtype=torch.float32)
    self.y_data   = torch.tensor(qrh_k1, dtype=torch.float32)
    self.msa_data = torch.tensor(msa_k1, dtype=torch.float32)

  def __len__(self):
    return len(self.x_data)

  def __getitem__(self, idx):
    if torch.is_tensor(idx):
      idx = idx.tolist()
    inp  = self.x_data[idx]
    outp = self.y_data[idx]
    msa  = self.msa_data[idx]
    sample = {'inp':inp, 'outp':outp, 'msa':msa}
    return sample

# %%
# Early stopping
def early_stop(list, min_epochs, patience):
    if(len(list) > min_epochs):
        if(np.max(list[-patience:]) < 1.0001*np.max(list[0: -patience])):
            return 1
    return 0

# %%
# train function
def train(net, p, train_ds, test_ds, lr=0.001, min_epochs=200, max_epochs=100000, patience=100, smooth=0):
    
    loss_func  = torch.nn.MSELoss()
    optimizer  = torch.optim.Adam(net.parameters(), lr=lr)

    train_ldr = torch.utils.data.DataLoader(train_ds, batch_size=256, shuffle=True)
    R2_qrh = np.array([])
    R2_msa = np.array([])
    for _ in range(0, max_epochs+1):
        net.train()
        loss  = 0
        count = 0
        for (_, batch) in enumerate(train_ldr):
            X    = batch['inp']
            Y    = batch['outp']

            optimizer.zero_grad()
            output = net(X)                    # compute the output of the Network
            loss_val = loss_func(output, Y) + smooth*loss_func(output, X[:,2].reshape(-1,1))
            loss += loss_val.item()            # accumulate
            loss_val.backward()                # gradients
            optimizer.step()                   # update paramters
            count += 1

        net.eval()
        R2_qrh = np.append(R2_qrh, eval(net, test_ds, p)[0].item())
        R2_msa = np.append(R2_msa, eval(net, test_ds, p)[1].item())
        
        if(early_stop(list = R2_qrh, min_epochs = min_epochs, patience = patience) == 1):
            break
    
    return R2_qrh, R2_msa

# %%
# main

for n_train in [32, 64, 128]:
    for _smooth in [0, 0.001, 0.01]:
        for h in [16, 32, 64]:
            for _lr in [0.0001, 0.001, 0.01, 0.1]:

                # Read data
                df = pd.read_csv('C:/Users/tln229/Downloads/Python/1. Building/data/HVAC_B90_102_exp_10m_20210424.csv')
                qrh = np.array(df['htg_valve_command']).reshape(-1,1)
                msa = np.array(df['airflow_desired']).reshape(-1,1)

                # LEAST SQUARE
                ones = np.ones(msa.shape)
                A = np.concatenate((qrh, ones), axis=1)
                b = np.copy(msa)
                p = np.linalg.lstsq(A, b, rcond=None)[0]

                # Create network
                device = torch.device("cpu")
                net = Net(h).to(device)

                # Create Dataset and DataLoader objects
                src_file = 'C:/Users/tln229/Downloads/Python/1. Building/data/HVAC_B90_102_exp_10m_20210424.csv'
                train_ds = Data(src_file, start=0, end=n_train)
                test_ds  = Data(src_file, start=n_train, end=1600)

                # train
                R2_qrh, R2_msa = train(net, p, train_ds, test_ds, lr=_lr, min_epochs=500, max_epochs=100000, patience=300, smooth=_smooth)

                # results
                print('n train = %3d \t smooth = %6.4f \t layer size = %2d \t lr = %6.4f \t best_epoch = %5d \t best_R2_qrh = %7.5f \t best_R2_msa = %7.5f'
                    % (n_train, _smooth, h, _lr, np.argmax(R2_qrh), np.max(R2_qrh), np.max(R2_msa)))
# Out:
# n train =  32 	 smooth = 0.0000 	 layer size = 16 	 lr = 0.0001 	 best_epoch = 22330 	 best_R2_qrh = -0.10843 	 best_R2_msa = -0.09329
# n train =  32 	 smooth = 0.0000 	 layer size = 16 	 lr = 0.0010 	 best_epoch =  5791 	 best_R2_qrh = 0.50360 	 best_R2_msa = 0.48735
# n train =  32 	 smooth = 0.0000 	 layer size = 16 	 lr = 0.0100 	 best_epoch =   423 	 best_R2_qrh = 0.00002 	 best_R2_msa = 0.00002
# n train =  32 	 smooth = 0.0000 	 layer size = 16 	 lr = 0.1000 	 best_epoch =     0 	 best_R2_qrh = -2.21354 	 best_R2_msa = -2.02209
# n train =  32 	 smooth = 0.0000 	 layer size = 32 	 lr = 0.0001 	 best_epoch =     0 	 best_R2_qrh = -2.21350 	 best_R2_msa = -2.02221
# n train =  32 	 smooth = 0.0000 	 layer size = 32 	 lr = 0.0010 	 best_epoch =  2506 	 best_R2_qrh = 0.22183 	 best_R2_msa = 0.21366
# n train =  32 	 smooth = 0.0000 	 layer size = 32 	 lr = 0.0100 	 best_epoch =   235 	 best_R2_qrh = 0.07641 	 best_R2_msa = 0.07341
# n train =  32 	 smooth = 0.0000 	 layer size = 32 	 lr = 0.1000 	 best_epoch =     0 	 best_R2_qrh = -2.21354 	 best_R2_msa = -2.02209
# n train =  32 	 smooth = 0.0000 	 layer size = 64 	 lr = 0.0001 	 best_epoch = 15224 	 best_R2_qrh = 0.73516 	 best_R2_msa = 0.71712
# n train =  32 	 smooth = 0.0000 	 layer size = 64 	 lr = 0.0010 	 best_epoch =     0 	 best_R2_qrh = -2.21354 	 best_R2_msa = -2.02209
# n train =  32 	 smooth = 0.0000 	 layer size = 64 	 lr = 0.0100 	 best_epoch =   105 	 best_R2_qrh = 0.03310 	 best_R2_msa = 0.03165
# n train =  32 	 smooth = 0.0000 	 layer size = 64 	 lr = 0.1000 	 best_epoch =     9 	 best_R2_qrh = 0.00370 	 best_R2_msa = 0.00417
# n train =  32 	 smooth = 0.0010 	 layer size = 16 	 lr = 0.0001 	 best_epoch = 36776 	 best_R2_qrh = 0.15911 	 best_R2_msa = 0.15257
# n train =  32 	 smooth = 0.0010 	 layer size = 16 	 lr = 0.0010 	 best_epoch =  6247 	 best_R2_qrh = 0.59570 	 best_R2_msa = 0.57762
# n train =  32 	 smooth = 0.0010 	 layer size = 16 	 lr = 0.0100 	 best_epoch =     0 	 best_R2_qrh = -2.21354 	 best_R2_msa = -2.02209
# n train =  32 	 smooth = 0.0010 	 layer size = 16 	 lr = 0.1000 	 best_epoch =     0 	 best_R2_qrh = -2.21354 	 best_R2_msa = -2.02209
# n train =  32 	 smooth = 0.0010 	 layer size = 32 	 lr = 0.0001 	 best_epoch = 20430 	 best_R2_qrh = 0.24764 	 best_R2_msa = 0.23745
# n train =  32 	 smooth = 0.0010 	 layer size = 32 	 lr = 0.0010 	 best_epoch =  4321 	 best_R2_qrh = 0.84512 	 best_R2_msa = 0.82868
# n train =  32 	 smooth = 0.0010 	 layer size = 32 	 lr = 0.0100 	 best_epoch =     0 	 best_R2_qrh = -2.21354 	 best_R2_msa = -2.02209
# n train =  32 	 smooth = 0.0010 	 layer size = 32 	 lr = 0.1000 	 best_epoch =    17 	 best_R2_qrh = -0.00050 	 best_R2_msa = -0.00073
# n train =  32 	 smooth = 0.0010 	 layer size = 64 	 lr = 0.0001 	 best_epoch =     0 	 best_R2_qrh = -2.21354 	 best_R2_msa = -2.02209
# n train =  32 	 smooth = 0.0010 	 layer size = 64 	 lr = 0.0010 	 best_epoch =     0 	 best_R2_qrh = -2.21354 	 best_R2_msa = -2.02209
# n train =  32 	 smooth = 0.0010 	 layer size = 64 	 lr = 0.0100 	 best_epoch =     0 	 best_R2_qrh = -2.21354 	 best_R2_msa = -2.02209
# n train =  32 	 smooth = 0.0010 	 layer size = 64 	 lr = 0.1000 	 best_epoch =     9 	 best_R2_qrh = 0.00930 	 best_R2_msa = 0.00859
# n train =  32 	 smooth = 0.0100 	 layer size = 16 	 lr = 0.0001 	 best_epoch = 47088 	 best_R2_qrh = 0.58823 	 best_R2_msa = 0.56921
# n train =  32 	 smooth = 0.0100 	 layer size = 16 	 lr = 0.0010 	 best_epoch =     0 	 best_R2_qrh = -2.21354 	 best_R2_msa = -2.02209
# n train =  32 	 smooth = 0.0100 	 layer size = 16 	 lr = 0.0100 	 best_epoch =   412 	 best_R2_qrh = -0.00000 	 best_R2_msa = -0.00000
# n train =  32 	 smooth = 0.0100 	 layer size = 16 	 lr = 0.1000 	 best_epoch =    36 	 best_R2_qrh = -0.00005 	 best_R2_msa = -0.00016
# n train =  32 	 smooth = 0.0100 	 layer size = 32 	 lr = 0.0001 	 best_epoch = 28874 	 best_R2_qrh = 0.94109 	 best_R2_msa = 0.92872
# n train =  32 	 smooth = 0.0100 	 layer size = 32 	 lr = 0.0010 	 best_epoch =     0 	 best_R2_qrh = -2.21354 	 best_R2_msa = -2.02209
# n train =  32 	 smooth = 0.0100 	 layer size = 32 	 lr = 0.0100 	 best_epoch =   210 	 best_R2_qrh = -0.00000 	 best_R2_msa = 0.00000
# n train =  32 	 smooth = 0.0100 	 layer size = 32 	 lr = 0.1000 	 best_epoch =    18 	 best_R2_qrh = 0.04083 	 best_R2_msa = 0.03894
# n train =  32 	 smooth = 0.0100 	 layer size = 64 	 lr = 0.0001 	 best_epoch = 13850 	 best_R2_qrh = 0.60678 	 best_R2_msa = 0.58843
# n train =  32 	 smooth = 0.0100 	 layer size = 64 	 lr = 0.0010 	 best_epoch =  4920 	 best_R2_qrh = 0.89815 	 best_R2_msa = 0.88603
# n train =  32 	 smooth = 0.0100 	 layer size = 64 	 lr = 0.0100 	 best_epoch =     0 	 best_R2_qrh = -2.21327 	 best_R2_msa = -2.02184
# n train =  32 	 smooth = 0.0100 	 layer size = 64 	 lr = 0.1000 	 best_epoch =   243 	 best_R2_qrh = 0.28557 	 best_R2_msa = 0.29502
# n train =  64 	 smooth = 0.0000 	 layer size = 16 	 lr = 0.0001 	 best_epoch = 58660 	 best_R2_qrh = 0.82749 	 best_R2_msa = 0.80859
# n train =  64 	 smooth = 0.0000 	 layer size = 16 	 lr = 0.0010 	 best_epoch =     0 	 best_R2_qrh = -2.24356 	 best_R2_msa = -2.05132
# n train =  64 	 smooth = 0.0000 	 layer size = 16 	 lr = 0.0100 	 best_epoch = 13817 	 best_R2_qrh = 0.96787 	 best_R2_msa = 0.96485
# n train =  64 	 smooth = 0.0000 	 layer size = 16 	 lr = 0.1000 	 best_epoch =    46 	 best_R2_qrh = -0.00000 	 best_R2_msa = -0.00000
# n train =  64 	 smooth = 0.0000 	 layer size = 32 	 lr = 0.0001 	 best_epoch =     0 	 best_R2_qrh = -2.24356 	 best_R2_msa = -2.05132
# n train =  64 	 smooth = 0.0000 	 layer size = 32 	 lr = 0.0010 	 best_epoch = 12146 	 best_R2_qrh = 0.93334 	 best_R2_msa = 0.93014
# n train =  64 	 smooth = 0.0000 	 layer size = 32 	 lr = 0.0100 	 best_epoch =  3104 	 best_R2_qrh = 0.95665 	 best_R2_msa = 0.95612
# n train =  64 	 smooth = 0.0000 	 layer size = 32 	 lr = 0.1000 	 best_epoch =    45 	 best_R2_qrh = -0.00004 	 best_R2_msa = -0.00001
# n train =  64 	 smooth = 0.0000 	 layer size = 64 	 lr = 0.0001 	 best_epoch = 17829 	 best_R2_qrh = 0.96267 	 best_R2_msa = 0.95925
# n train =  64 	 smooth = 0.0000 	 layer size = 64 	 lr = 0.0010 	 best_epoch =  8069 	 best_R2_qrh = 0.96106 	 best_R2_msa = 0.95869
# n train =  64 	 smooth = 0.0000 	 layer size = 64 	 lr = 0.0100 	 best_epoch =  2651 	 best_R2_qrh = 0.96236 	 best_R2_msa = 0.96113
# n train =  64 	 smooth = 0.0000 	 layer size = 64 	 lr = 0.1000 	 best_epoch =   379 	 best_R2_qrh = 0.87143 	 best_R2_msa = 0.85918
# n train =  64 	 smooth = 0.0010 	 layer size = 16 	 lr = 0.0001 	 best_epoch = 52243 	 best_R2_qrh = 0.83079 	 best_R2_msa = 0.81366
# n train =  64 	 smooth = 0.0010 	 layer size = 16 	 lr = 0.0010 	 best_epoch = 11032 	 best_R2_qrh = 0.94083 	 best_R2_msa = 0.93757
# n train =  64 	 smooth = 0.0010 	 layer size = 16 	 lr = 0.0100 	 best_epoch =  8795 	 best_R2_qrh = 0.96067 	 best_R2_msa = 0.95562
# n train =  64 	 smooth = 0.0010 	 layer size = 16 	 lr = 0.1000 	 best_epoch =    45 	 best_R2_qrh = -0.00000 	 best_R2_msa = -0.00000
# n train =  64 	 smooth = 0.0010 	 layer size = 32 	 lr = 0.0001 	 best_epoch = 43390 	 best_R2_qrh = 0.83648 	 best_R2_msa = 0.81785
# n train =  64 	 smooth = 0.0010 	 layer size = 32 	 lr = 0.0010 	 best_epoch =     0 	 best_R2_qrh = -2.24356 	 best_R2_msa = -2.05132
# n train =  64 	 smooth = 0.0010 	 layer size = 32 	 lr = 0.0100 	 best_epoch =  2579 	 best_R2_qrh = 0.94789 	 best_R2_msa = 0.94587
# n train =  64 	 smooth = 0.0010 	 layer size = 32 	 lr = 0.1000 	 best_epoch =    43 	 best_R2_qrh = -0.00001 	 best_R2_msa = -0.00001
# n train =  64 	 smooth = 0.0010 	 layer size = 64 	 lr = 0.0001 	 best_epoch = 29931 	 best_R2_qrh = 0.95247 	 best_R2_msa = 0.94731
# n train =  64 	 smooth = 0.0010 	 layer size = 64 	 lr = 0.0010 	 best_epoch =  3337 	 best_R2_qrh = 0.96022 	 best_R2_msa = 0.95598
# n train =  64 	 smooth = 0.0010 	 layer size = 64 	 lr = 0.0100 	 best_epoch =  1188 	 best_R2_qrh = 0.96407 	 best_R2_msa = 0.96315
# n train =  64 	 smooth = 0.0010 	 layer size = 64 	 lr = 0.1000 	 best_epoch =     0 	 best_R2_qrh = -2.24356 	 best_R2_msa = -2.05132
# n train =  64 	 smooth = 0.0100 	 layer size = 16 	 lr = 0.0001 	 best_epoch = 49162 	 best_R2_qrh = 0.86624 	 best_R2_msa = 0.84891
# n train =  64 	 smooth = 0.0100 	 layer size = 16 	 lr = 0.0010 	 best_epoch = 12770 	 best_R2_qrh = 0.93694 	 best_R2_msa = 0.93598
# n train =  64 	 smooth = 0.0100 	 layer size = 16 	 lr = 0.0100 	 best_epoch = 17074 	 best_R2_qrh = -0.00065 	 best_R2_msa = -0.00092
# n train =  64 	 smooth = 0.0100 	 layer size = 16 	 lr = 0.1000 	 best_epoch =    74 	 best_R2_qrh = -0.00000 	 best_R2_msa = -0.00000
# n train =  64 	 smooth = 0.0100 	 layer size = 32 	 lr = 0.0001 	 best_epoch = 50872 	 best_R2_qrh = 0.86507 	 best_R2_msa = 0.85495
# n train =  64 	 smooth = 0.0100 	 layer size = 32 	 lr = 0.0010 	 best_epoch =  7106 	 best_R2_qrh = 0.95504 	 best_R2_msa = 0.95294
# n train =  64 	 smooth = 0.0100 	 layer size = 32 	 lr = 0.0100 	 best_epoch =  2361 	 best_R2_qrh = 0.96466 	 best_R2_msa = 0.96073
# n train =  64 	 smooth = 0.0100 	 layer size = 32 	 lr = 0.1000 	 best_epoch =     0 	 best_R2_qrh = -2.24356 	 best_R2_msa = -2.05132
# n train =  64 	 smooth = 0.0100 	 layer size = 64 	 lr = 0.0001 	 best_epoch = 21607 	 best_R2_qrh = 0.96126 	 best_R2_msa = 0.95903
# n train =  64 	 smooth = 0.0100 	 layer size = 64 	 lr = 0.0010 	 best_epoch =  5190 	 best_R2_qrh = 0.95950 	 best_R2_msa = 0.95942
# n train =  64 	 smooth = 0.0100 	 layer size = 64 	 lr = 0.0100 	 best_epoch =  2520 	 best_R2_qrh = 0.96795 	 best_R2_msa = 0.96465
# n train =  64 	 smooth = 0.0100 	 layer size = 64 	 lr = 0.1000 	 best_epoch =   407 	 best_R2_qrh = 0.87546 	 best_R2_msa = 0.86878
# n train = 128 	 smooth = 0.0000 	 layer size = 16 	 lr = 0.0001 	 best_epoch = 86324 	 best_R2_qrh = 0.85907 	 best_R2_msa = 0.85092
# n train = 128 	 smooth = 0.0000 	 layer size = 16 	 lr = 0.0010 	 best_epoch = 27307 	 best_R2_qrh = 0.95767 	 best_R2_msa = 0.95535
# n train = 128 	 smooth = 0.0000 	 layer size = 16 	 lr = 0.0100 	 best_epoch =     0 	 best_R2_qrh = -2.52712 	 best_R2_msa = -2.31898
# n train = 128 	 smooth = 0.0000 	 layer size = 16 	 lr = 0.1000 	 best_epoch =    31 	 best_R2_qrh = -0.40262 	 best_R2_msa = -0.37614
# n train = 128 	 smooth = 0.0000 	 layer size = 32 	 lr = 0.0001 	 best_epoch =     0 	 best_R2_qrh = -2.52712 	 best_R2_msa = -2.31898
# n train = 128 	 smooth = 0.0000 	 layer size = 32 	 lr = 0.0010 	 best_epoch =  7244 	 best_R2_qrh = 0.95439 	 best_R2_msa = 0.94688
# n train = 128 	 smooth = 0.0000 	 layer size = 32 	 lr = 0.0100 	 best_epoch =  6548 	 best_R2_qrh = 0.97225 	 best_R2_msa = 0.96934
# n train = 128 	 smooth = 0.0000 	 layer size = 32 	 lr = 0.1000 	 best_epoch =     0 	 best_R2_qrh = -2.52712 	 best_R2_msa = -2.31898
# n train = 128 	 smooth = 0.0000 	 layer size = 64 	 lr = 0.0001 	 best_epoch = 30570 	 best_R2_qrh = 0.96404 	 best_R2_msa = 0.96022
# n train = 128 	 smooth = 0.0000 	 layer size = 64 	 lr = 0.0010 	 best_epoch =  5013 	 best_R2_qrh = 0.96299 	 best_R2_msa = 0.95999
# n train = 128 	 smooth = 0.0000 	 layer size = 64 	 lr = 0.0100 	 best_epoch =     0 	 best_R2_qrh = -2.52712 	 best_R2_msa = -2.31898
# n train = 128 	 smooth = 0.0000 	 layer size = 64 	 lr = 0.1000 	 best_epoch =   101 	 best_R2_qrh = 0.90750 	 best_R2_msa = 0.89276
# n train = 128 	 smooth = 0.0010 	 layer size = 16 	 lr = 0.0001 	 best_epoch = 100000 	 best_R2_qrh = 0.91050 	 best_R2_msa = 0.89853
# n train = 128 	 smooth = 0.0010 	 layer size = 16 	 lr = 0.0010 	 best_epoch =     0 	 best_R2_qrh = -2.52712 	 best_R2_msa = -2.31898
# n train = 128 	 smooth = 0.0010 	 layer size = 16 	 lr = 0.0100 	 best_epoch = 15350 	 best_R2_qrh = -0.57655 	 best_R2_msa = -0.53601
# n train = 128 	 smooth = 0.0010 	 layer size = 16 	 lr = 0.1000 	 best_epoch =     0 	 best_R2_qrh = -2.52712 	 best_R2_msa = -2.31898
# n train = 128 	 smooth = 0.0010 	 layer size = 32 	 lr = 0.0001 	 best_epoch = 45876 	 best_R2_qrh = 0.96035 	 best_R2_msa = 0.95614
# n train = 128 	 smooth = 0.0010 	 layer size = 32 	 lr = 0.0010 	 best_epoch =  9604 	 best_R2_qrh = 0.95704 	 best_R2_msa = 0.95329
# n train = 128 	 smooth = 0.0010 	 layer size = 32 	 lr = 0.0100 	 best_epoch =  2531 	 best_R2_qrh = 0.96792 	 best_R2_msa = 0.96481
# n train = 128 	 smooth = 0.0010 	 layer size = 32 	 lr = 0.1000 	 best_epoch =    17 	 best_R2_qrh = -0.27198 	 best_R2_msa = -0.25573
# n train = 128 	 smooth = 0.0010 	 layer size = 64 	 lr = 0.0001 	 best_epoch = 29813 	 best_R2_qrh = 0.96355 	 best_R2_msa = 0.95951
# n train = 128 	 smooth = 0.0010 	 layer size = 64 	 lr = 0.0010 	 best_epoch =     0 	 best_R2_qrh = -2.52712 	 best_R2_msa = -2.31898
# n train = 128 	 smooth = 0.0010 	 layer size = 64 	 lr = 0.0100 	 best_epoch =  2061 	 best_R2_qrh = 0.96709 	 best_R2_msa = 0.96535
# n train = 128 	 smooth = 0.0010 	 layer size = 64 	 lr = 0.1000 	 best_epoch =   214 	 best_R2_qrh = 0.92809 	 best_R2_msa = 0.92467
# n train = 128 	 smooth = 0.0100 	 layer size = 16 	 lr = 0.0001 	 best_epoch = 89022 	 best_R2_qrh = 0.93877 	 best_R2_msa = 0.93019
# n train = 128 	 smooth = 0.0100 	 layer size = 16 	 lr = 0.0010 	 best_epoch = 28464 	 best_R2_qrh = 0.95765 	 best_R2_msa = 0.95525
# n train = 128 	 smooth = 0.0100 	 layer size = 16 	 lr = 0.0100 	 best_epoch =     0 	 best_R2_qrh = -2.52712 	 best_R2_msa = -2.31898
# n train = 128 	 smooth = 0.0100 	 layer size = 16 	 lr = 0.1000 	 best_epoch =    30 	 best_R2_qrh = -0.39550 	 best_R2_msa = -0.36960
# n train = 128 	 smooth = 0.0100 	 layer size = 32 	 lr = 0.0001 	 best_epoch = 54096 	 best_R2_qrh = 0.95822 	 best_R2_msa = 0.95449
# n train = 128 	 smooth = 0.0100 	 layer size = 32 	 lr = 0.0010 	 best_epoch = 11429 	 best_R2_qrh = 0.93827 	 best_R2_msa = 0.93327
# n train = 128 	 smooth = 0.0100 	 layer size = 32 	 lr = 0.0100 	 best_epoch =  3196 	 best_R2_qrh = 0.96149 	 best_R2_msa = 0.96139
# n train = 128 	 smooth = 0.0100 	 layer size = 32 	 lr = 0.1000 	 best_epoch =   448 	 best_R2_qrh = 0.74749 	 best_R2_msa = 0.73733
# n train = 128 	 smooth = 0.0100 	 layer size = 64 	 lr = 0.0001 	 best_epoch = 33328 	 best_R2_qrh = 0.96243 	 best_R2_msa = 0.95899
# n train = 128 	 smooth = 0.0100 	 layer size = 64 	 lr = 0.0010 	 best_epoch =  4679 	 best_R2_qrh = 0.96396 	 best_R2_msa = 0.96098
# n train = 128 	 smooth = 0.0100 	 layer size = 64 	 lr = 0.0100 	 best_epoch =   827 	 best_R2_qrh = 0.96743 	 best_R2_msa = 0.96491
# n train = 128 	 smooth = 0.0100 	 layer size = 64 	 lr = 0.1000 	 best_epoch =   558 	 best_R2_qrh = 0.87353 	 best_R2_msa = 0.87399
