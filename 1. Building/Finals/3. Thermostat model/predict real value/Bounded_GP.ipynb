# %%
import sys
import numpy as np
import pandas as pd
from sklearn.metrics import r2_score

### Custom files ###
dir_gp_constr = 'C:\\Users\\tln229\\Downloads\\Python Tests\\Constrained GP_2\\GP_2\\gp_constr\\'
sys.path.append(dir_gp_constr)

# Import
from GPConstr.model import GPmodel, Constraint
from GPConstr.kern import kernel_Matern52
# Out:
# Unable to determine R home: [WinError 2] The system cannot find the file specified
# R[write to console]: Loading required package: mvtnorm
# Loading constrained GP module from C:\Users\tln229\Downloads\Python\1. Building\Finals\3. Thermostat model\predict real value
# Loading R wrapper...
# R[write to console]: Loading required package: Matrix
#
# R[write to console]: Loading required package: stats4
#
# R[write to console]: Loading required package: gmm
#
# R[write to console]: Loading required package: sandwich
#
# R[write to console]:
# Attaching package: 'TruncatedNormal'
#
#
# R[write to console]: The following objects are masked from 'package:tmvtnorm':
#
#     dtmvnorm, dtmvt, ptmvnorm, ptmvt, rtmvnorm, rtmvt
#
#
# R[write to console]: The following objects are masked from 'package:mvtnorm':
#
#     pmvnorm, pmvt
# Running R from rpy2: R version 4.2.2 (2022-10-31 ucrt)

# %%
def get_diagnostics_df(x_test, y_test, mean, var):
    """ Put test data in a dataframe"""
    df = pd.DataFrame(x_test)
    df.columns = ['x' + str(i+1) for i in range(x_test.shape[1])]
    df['y_true'] = y_test
    df['y_mean'] = mean
    df['y_var'] = var
    return df

# %%
def constant_function(val):
    def fun(x):
        return np.array([val]*x.shape[0])
    return fun

# %%
# ---------- DATA ----------
def create_data(n_train, n_Xv):
    df = pd.read_csv('C:/Users/tln229/Downloads/Python/1. Building/data/HVAC_B90_102_exp_10m_20210424.csv')

    # TRAIN SET
    clg_sp       = np.array(df['clg_sp_current']).reshape(-1,1)[0: n_train]
    htg_sp       = np.array(df['htg_sp_current']).reshape(-1,1)[0: n_train]
    htg_clg_mode = 1*np.array(df['htg_clg_mode']).reshape(-1,1)[0: n_train]

    sp_k   = htg_sp*htg_clg_mode + clg_sp*(1-htg_clg_mode)
    Tz_k   = np.array(df['thermostat_room_temp']).reshape(-1,1)[0: n_train]
    qrh_k  = np.array(df['htg_valve_position']).reshape(-1,1)[0: n_train]
    qrh_k1 = np.array(df['htg_valve_position'])[0+1: n_train+1]

    x_train  = np.concatenate((sp_k, Tz_k, qrh_k), axis=1)
    y_train = qrh_k1

    # Xv
    x1v = np.linspace(68, 76, n_Xv).reshape(-1, 1)
    x2v = np.linspace(68, 75, n_Xv).reshape(-1, 1)
    x3v = np.linspace(0, 100, n_Xv).reshape(-1, 1)
    Xv  = np.concatenate((x1v, x2v, x3v), axis = 1)

    # TEST SET
    clg_sp       = np.array(df['clg_sp_current']).reshape(-1,1)[n_train: 1600]
    htg_sp       = np.array(df['htg_sp_current']).reshape(-1,1)[n_train: 1600]
    htg_clg_mode = 1*np.array(df['htg_clg_mode']).reshape(-1,1)[n_train: 1600]

    sp_k   = htg_sp*htg_clg_mode + clg_sp*(1-htg_clg_mode)
    Tz_k   = np.array(df['thermostat_room_temp']).reshape(-1,1)[n_train: 1600]
    qrh_k  = np.array(df['htg_valve_position']).reshape(-1,1)[n_train: 1600]
    qrh_k1 = np.array(df['htg_valve_position'])[n_train+1: 1600+1]
    msa_k1 = np.array(df['airflow_current'])[n_train+1: 1600+1]

    x_test  = np.concatenate((sp_k, Tz_k, qrh_k), axis=1)
    y_test  = qrh_k1
    y2_test = msa_k1

    return x_train, y_train, Xv, x_test, y_test, y2_test

# %%
df_result = pd.DataFrame({'n_train':[], 'n_Xv':[], 'R2_qrh':[], 'R2_msa':[]})

for n_train in ([32, 64, 128]):
    for n_Xv in ([5, 10, 15]):
        # DATA
        x_train, y_train, Xv, x_test, y_test, y2_test = create_data(n_train=n_train, n_Xv=n_Xv)

        # MODEL
        ker = kernel_Matern52(variance = 0.1, lengthscale = [0.1]*x_train.shape[1])
        model = GPmodel(kernel = ker, likelihood = 1E-4, mean = 0)

        model.X_training = x_train
        model.Y_training = y_train

        model.optimize(include_constraint = False, fix_likelihood = False)

        # CONSTRAINTS
        model.constr_bounded    = Constraint(LB = constant_function(0), UB = constant_function(100))
        model.constr_bounded.Xv = Xv
        model.constr_likelihood = 1E-6

        # PREDICT qrh
        mean, _, _, _, _, _ = model.calc_posterior_constrained(x_test, num_samples = 5000, save_samples = 500)
        mean = np.array(mean).flatten()

        # PREDICT msa
        df = pd.read_csv('C:/Users/tln229/Downloads/Python/1. Building/data/HVAC_B90_102_exp_10m_20210424.csv')
        qrh = np.array(df['htg_valve_position']).reshape(-1,1)[0: n_train]
        msa = np.array(df['airflow_current']).reshape(-1,1)[0: n_train]

        A = np.concatenate((qrh, np.ones(msa.shape)), axis=1)
        b = np.copy(msa)
        p = np.linalg.lstsq(A, b, rcond=None)[0]
        pred_msa = mean*p[0] + p[1]

        print(n_train, n_Xv, r2_score(y_test, mean), r2_score(y2_test, pred_msa))

        df_result.loc[len(df_result)] = [n_train, n_Xv, r2_score(y_test, mean), r2_score(y2_test, pred_msa)]
# Out:
# ..Running optimization for unconstrained GP ... DONE - Total time: 0.052 seconds
# ..Running calculation of K_w ... SKIP - (cached)
# ..Running calculation of Cholesky factor for K_w ... SKIP - (cached)
# ..Running preparation step 1 - dependence on (XS, X) ... DONE - time: 0.109 seconds
# ..Running preparation step 2 - dependence on (XV, X) ... DONE - time: 0.000 seconds
# ..Running preparation step 3 - dependence on (XS, XV, X) ... DONE - time: 0.013 seconds
# ..sampling 5000 times from truncated constraint distribution C~|C, Y DONE - time: 0.011 seconds
# ..sampling 5000 times from constrained GP f*|C, Y DONE - time: 4.242 seconds
# ..computing statistics from samples DONE - time: 0.200 seconds
#  DONE - Total time: 4.577 seconds
# WARNING: covariance matrix not PD! -- used closest PD matrix, error = 4.437256393430289e-07
# 32 5 -1.1248460306856547 -1.091311525165072
# ..Running optimization for unconstrained GP ... DONE - Total time: 0.053 seconds
# ..Running calculation of K_w ... SKIP - (cached)
# ..Running calculation of Cholesky factor for K_w ... SKIP - (cached)
# ..Running preparation step 1 - dependence on (XS, X) ... DONE - time: 0.112 seconds
# ..Running preparation step 2 - dependence on (XV, X) ... DONE - time: 0.000 seconds
# ..Running preparation step 3 - dependence on (XS, XV, X) ... DONE - time: 0.013 seconds
# ..sampling 5000 times from truncated constraint distribution C~|C, Y DONE - time: 0.023 seconds
# ..sampling 5000 times from constrained GP f*|C, Y DONE - time: 4.315 seconds
# ..computing statistics from samples DONE - time: 0.210 seconds
#  DONE - Total time: 4.674 seconds
# WARNING: covariance matrix not PD! -- used closest PD matrix, error = 4.4372586671670433e-07
# 32 10 -1.1252693829092522 -1.0917993139475586
# ..Running optimization for unconstrained GP ... DONE - Total time: 0.059 seconds
# ..Running calculation of K_w ... SKIP - (cached)
# ..Running calculation of Cholesky factor for K_w ... SKIP - (cached)
# ..Running preparation step 1 - dependence on (XS, X) ... DONE - time: 0.125 seconds
# ..Running preparation step 2 - dependence on (XV, X) ... DONE - time: 0.000 seconds
# ..Running preparation step 3 - dependence on (XS, XV, X) ... DONE - time: 0.016 seconds
# ..sampling 5000 times from truncated constraint distribution C~|C, Y DONE - time: 0.030 seconds
# ..sampling 5000 times from constrained GP f*|C, Y DONE - time: 4.623 seconds
# ..computing statistics from samples DONE - time: 0.213 seconds
#  DONE - Total time: 5.009 seconds
# WARNING: covariance matrix not PD! -- used closest PD matrix, error = 4.437256393430289e-07
# 32 15 -1.1339393255533574 -1.0984449318690204
# ..Running optimization for unconstrained GP ... DONE - Total time: 0.108 seconds
# ..Running calculation of K_w ... SKIP - (cached)
# ..Running calculation of Cholesky factor for K_w ... SKIP - (cached)
# ..Running preparation step 1 - dependence on (XS, X) ... DONE - time: 0.118 seconds
# ..Running preparation step 2 - dependence on (XV, X) ... DONE - time: 0.001 seconds
# ..Running preparation step 3 - dependence on (XS, XV, X) ... DONE - time: 0.014 seconds
# ..sampling 5000 times from truncated constraint distribution C~|C, Y DONE - time: 0.009 seconds
# ..sampling 5000 times from constrained GP f*|C, Y DONE - time: 4.426 seconds
# ..computing statistics from samples DONE - time: 0.196 seconds
#  DONE - Total time: 4.764 seconds
# WARNING: covariance matrix not PD! -- used closest PD matrix, error = 2.1949290385236964e-07
# 64 5 -0.8734158093362154 -0.8337142552430041
# ..Running optimization for unconstrained GP ... DONE - Total time: 0.105 seconds
# ..Running calculation of K_w ... SKIP - (cached)
# ..Running calculation of Cholesky factor for K_w ... SKIP - (cached)
# ..Running preparation step 1 - dependence on (XS, X) ... DONE - time: 0.113 seconds
# ..Running preparation step 2 - dependence on (XV, X) ... DONE - time: 0.001 seconds
# ..Running preparation step 3 - dependence on (XS, XV, X) ... DONE - time: 0.015 seconds
# ..sampling 5000 times from truncated constraint distribution C~|C, Y DONE - time: 0.020 seconds
# ..sampling 5000 times from constrained GP f*|C, Y DONE - time: 4.378 seconds
# ..computing statistics from samples DONE - time: 0.196 seconds
#  DONE - Total time: 4.723 seconds
# WARNING: covariance matrix not PD! -- used closest PD matrix, error = 2.1948835637886077e-07
# 64 10 -0.8768951756707348 -0.8378808984959907
# ..Running optimization for unconstrained GP ... DONE - Total time: 0.117 seconds
# ..Running calculation of K_w ... SKIP - (cached)
# ..Running calculation of Cholesky factor for K_w ... SKIP - (cached)
# ..Running preparation step 1 - dependence on (XS, X) ... DONE - time: 0.108 seconds
# ..Running preparation step 2 - dependence on (XV, X) ... DONE - time: 0.001 seconds
# ..Running preparation step 3 - dependence on (XS, XV, X) ... DONE - time: 0.016 seconds
# ..sampling 5000 times from truncated constraint distribution C~|C, Y DONE - time: 0.029 seconds
# ..sampling 5000 times from constrained GP f*|C, Y DONE - time: 4.349 seconds
# ..computing statistics from samples DONE - time: 0.200 seconds
#  DONE - Total time: 4.702 seconds
# WARNING: covariance matrix not PD! -- used closest PD matrix, error = 2.1949290385236964e-07
# 64 15 -0.8713080290900814 -0.8319040931992383
# ..Running optimization for unconstrained GP ... DONE - Total time: 0.455 seconds
# ..Running calculation of K_w ... SKIP - (cached)
# ..Running calculation of Cholesky factor for K_w ... SKIP - (cached)
# ..Running preparation step 1 - dependence on (XS, X) ... DONE - time: 0.066 seconds
# ..Running preparation step 2 - dependence on (XV, X) ... DONE - time: 0.000 seconds
# ..Running preparation step 3 - dependence on (XS, XV, X) ... DONE - time: 0.011 seconds
# ..sampling 5000 times from truncated constraint distribution C~|C, Y DONE - time: 0.010 seconds
# ..sampling 5000 times from constrained GP f*|C, Y DONE - time: 2.404 seconds
# ..computing statistics from samples DONE - time: 0.185 seconds
#  DONE - Total time: 2.678 seconds
# WARNING: covariance matrix not PD! -- used closest PD matrix, error = 2.9107827259622354e-11
# 128 5 0.948870164809537 0.9456305350621611
# ..Running optimization for unconstrained GP ... DONE - Total time: 0.418 seconds
# ..Running calculation of K_w ... SKIP - (cached)
# ..Running calculation of Cholesky factor for K_w ... SKIP - (cached)
# ..Running preparation step 1 - dependence on (XS, X) ... DONE - time: 0.069 seconds
# ..Running preparation step 2 - dependence on (XV, X) ... DONE - time: 0.001 seconds
# ..Running preparation step 3 - dependence on (XS, XV, X) ... DONE - time: 0.012 seconds
# ..sampling 5000 times from truncated constraint distribution C~|C, Y DONE - time: 0.019 seconds
# ..sampling 5000 times from constrained GP f*|C, Y DONE - time: 2.446 seconds
# ..computing statistics from samples DONE - time: 0.184 seconds
#  DONE - Total time: 2.731 seconds
# WARNING: covariance matrix not PD! -- used closest PD matrix, error = 2.9104718635153404e-11
# 128 10 0.9555330949964332 0.9519037293968997
# ..Running optimization for unconstrained GP ... DONE - Total time: 0.423 seconds
# ..Running calculation of K_w ... SKIP - (cached)
# ..Running calculation of Cholesky factor for K_w ... SKIP - (cached)
# ..Running preparation step 1 - dependence on (XS, X) ... DONE - time: 0.072 seconds
# ..Running preparation step 2 - dependence on (XV, X) ... DONE - time: 0.001 seconds
# ..Running preparation step 3 - dependence on (XS, XV, X) ... DONE - time: 0.012 seconds
# ..sampling 5000 times from truncated constraint distribution C~|C, Y DONE - time: 0.064 seconds
# ..sampling 5000 times from constrained GP f*|C, Y DONE - time: 2.437 seconds
# ..computing statistics from samples DONE - time: 0.194 seconds
#  DONE - Total time: 2.781 seconds
# WARNING: covariance matrix not PD! -- used closest PD matrix, error = 2.9108271348832204e-11
# 128 15 0.9558214821344037 0.9522130276392691

# %%
print(df_result)
# Out:
#    n_train  n_Xv    R2_qrh    R2_msa
# 0     32.0   5.0 -1.124846 -1.091312
# 1     32.0  10.0 -1.125269 -1.091799
# 2     32.0  15.0 -1.133939 -1.098445
# 3     64.0   5.0 -0.873416 -0.833714
# 4     64.0  10.0 -0.876895 -0.837881
# 5     64.0  15.0 -0.871308 -0.831904
# 6    128.0   5.0  0.948870  0.945631
# 7    128.0  10.0  0.955533  0.951904
# 8    128.0  15.0  0.955821  0.952213
